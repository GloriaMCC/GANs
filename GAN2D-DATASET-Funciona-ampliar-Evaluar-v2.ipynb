# %%
import torch
import tensorflow
from tensorflow.python.client import device_lib
def print_info():
    print('  Versión de TensorFlow: {}'.format(tensorflow.__version__))
    print('  GPU: {}'.format([x.physical_device_desc for x in device_lib.list_local_devices() if x.device_type == 'GPU']))
    print('  Versión Cuda  -> {}'.format(tensorflow.sysconfig.get_build_info()['cuda_version']))
    print('  Versión Cudnn -> {}\n'.format(tensorflow.sysconfig.get_build_info()['cudnn_version']))

print_info()
# Out:
#   Versión de TensorFlow: 2.9.0
#   GPU: ['device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5']
#   Versión Cuda  -> 64_112
#   Versión Cudnn -> 64_8

# %%
#Import from library
from datetime import date, time, datetime
import numpy as np
import pandas as pd
import os
import cv2
#mediciones librerias
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from skimage.measure import label, regionprops, regionprops_table
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KernelDensity
from sklearn.metrics import pairwise_distances
from skimage.metrics import structural_similarity as ssim
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing import image
from scipy.linalg import sqrtm
from scipy.stats import entropy
from scipy.stats import norm
#acomodar imagenes
from os import makedirs
#Importar librerias
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import vstack
from numpy.random import randn
from numpy.random import randint
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.layers import MaxPooling2D
from keras.layers import LayerNormalization, BatchNormalization
#from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
# example of loading the mnist dataset
from keras.datasets.mnist import load_data
# load saved models
from keras.models import load_model

# %%
# Directorio que contiene tus imágenes
data_dir = 'Imagenes\data_all'

# Obtén la lista de nombres de archivo de las imágenes
image_filenames = sorted(os.listdir(data_dir))

# Crea un DataFrame de pandas con las rutas de las imágenes
df = pd.DataFrame({'filename': image_filenames})

# Configurar el generador de imágenes
image_size = (224, 224)
batch_size = 32

# Puedes aplicar aumentos de datos si lo deseas
data_generator = ImageDataGenerator(rescale=1./255,  # Normalizar los valores de píxeles
                                   )

# Crear un generador de lotes para el conjunto de datos de entrenamiento
train_generator = data_generator.flow_from_dataframe(
    df,
    directory=data_dir,
    x_col='filename',
    y_col=None,
    target_size=image_size,
    batch_size=16,
    class_mode=None,  # No hay clases específicas
    shuffle=True,
    seed=42,  # Para reproducibilidad
    color_mode = 'grayscale',
)


# Obtener el número total de muestras en el conjunto de datos
total_samples = len(train_generator.filenames)

# Obtener el número total de pasos por época
steps_per_epoch = total_samples // batch_size

# Imprimir información sobre el conjunto de datos
print("Total de muestras:", total_samples)
print("Pasos por época:", steps_per_epoch)
# Out:
# Found 5200 validated image filenames.
# Total de muestras: 5200
# Pasos por época: 162

# %%
## Creacion de Dataset
data_img=[]
for num in range(1,5201):
    num_img = str(num).rjust(5,'0')
    dir_img = 'Imagenes\data_all\{}.png'.format(num_img)
    temp_img= cv2.imread(dir_img, cv2.IMREAD_GRAYSCALE)
    #th, im_th = cv2.threshold(temp_img, 128, 255, cv2.THRESH_BINARY)
    #plt.imshow(temp_img)
    resize = cv2.resize(temp_img,(56,56),interpolation = cv2.INTER_CUBIC)
    data_img.append(resize)
data_img = np.asarray(data_img)
data_img = data_img / 255.0
data_img = data_img.reshape(5200,56,56,1)

# %%
# plot images from the training dataset
for i in range(25):
    # define subplot
    plt.subplot(5, 5, 1 + i)
    # turn off axis
    plt.axis('off')
    # plot raw pixel data
    plt.imshow(data_img[i], cmap='gray_r')
#filename = 'base_plot_2DGAN{}.png'.format(str(date.today()))
#plt.savefig(filename)
#plt.close()
#summarize the shape of the dataset
print(data_img.shape)
# Out:
# (5200, 56, 56, 1)

# %%
# define the standalone dicriminator model
def define_discriminator(in_shape=(224,224,1)):
    model = Sequential()
    model.add(Conv2D(32,
                     (3,3),
                     strides=(2,2),
                     padding='same',
                     input_shape=in_shape))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    #model.add(LayerNormalization())
    model.add(Conv2D(64,
                     (3,3),
                     strides=(2,2),
                     padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    
    model.add(Conv2D(64,
                     (3,3),
                     strides=(2,2),
                     padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    #model.add(LayerNormalization())
    
    model.add(Conv2D(128,
                     (3,3),
                     strides=(2,2),
                     padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    
    model.add(Conv2D(128,
                     (3,3),
                     strides=(2,2),
                     padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    #model.add(LayerNormalization())
    
    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(1,
                    activation='sigmoid'))
    model.summary()
    #compile model
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(optimizer=opt,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
#define the standalone generator model
def define_generator(latent_dim):
    model = Sequential()
    #foundation for 7x7 image
    n_nodes =256 *7*7 #features maps*dimensions
    model.add(Dense(n_nodes,
                    input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Reshape((7, 7, 256)))
    #model.add(LayerNormalization())
    
    # upsample to 14x14
    model.add(Conv2DTranspose(128,
                              (3,3),
                              strides=(2,2),
                              padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    # upsample to 28x28
    model.add(Conv2DTranspose(64,
                              (3,3),
                              strides=(2,2),
                              padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 56x56
    model.add(Conv2DTranspose(32,
                              (3,3),
                              strides=(2,2),
                              padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    
    #model.add(LayerNormalization())
    # upsample to 112x112
    model.add(Conv2DTranspose(16,
                              (3,3),
                              strides=(2,2),
                              padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 224x224
    model.add(Conv2DTranspose(16,
                              (3,3),
                              strides=(2,2),
                              padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    #model.add(LayerNormalization())
    
    model.add(Conv2D(1,
                     (7,7),
                     activation='sigmoid',
                     padding='same'))
    model.summary()
    return model

# %%
#define the combined generator and dicriminatro model,
#for updating the generator
def define_gan(g_model,d_model):
    #make weights in the discriminator not trainable
    d_model.trainable = False
    #connect them
    model = Sequential()
    # add generator
    model.add(g_model)
    #add the discriminator
    model.add(d_model)
    model.summary()
    #compile model
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(optimizer=opt,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
## load and prepare mnist training images
def load_real_samples():
    # load mnist dataset
    (trainX, _), (_, _) = data_img
    #(trainX, _), (_, _) = load_data()
    # expand to 3d, e.g. add channels dimension
    X = expand_dims(trainX, axis=-1)
    # convert from unsigned ints to floats
    X = X.astype('float32')
    # scale from [0,255] to [0,1]
    X = X / 255.0
    #X = (X-127.5) / 127.5
    return X

# %%
# select real samples
def generate_real_samples(dataset, n_samples):
    # choose random instances
    ix = randint(0, dataset.shape[0], n_samples)
    # retrieve selected images
    X = dataset[ix]
    # generate ✬real✬ class labels (1)
    y = ones((n_samples, 1))
    return X, y

# %%
def generate_real_samples_v2(n_samples):
    
    # Obtener un lote de muestras reales del generador de imágenes
    batch = train_generator.next()
    #print(batch.shape)
    #X = batch[0]  # La primera parte del lote son las imágenes
    #print(X.shape)
    #print(batch[1].shape)
    # generate ✬real✬ class labels (1)
    y = ones((n_samples, 1))
    
    return batch, y

# %%
#X,y = generate_real_samples_v2(batch_size/2)

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
    # generate points in the latent space
    x_input = randn(latent_dim * n_samples)
    # reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, latent_dim)
    return x_input

# %%
# use the generator to generate n fake examples, with class labels
def generate_fake_samples(g_model, latent_dim, n_samples):
    # generate points in latent space
    x_input = generate_latent_points(latent_dim, n_samples)
    # predict outputs
    X = g_model.predict(x_input)
    # create ✬fake✬ class labels (0)
    y = zeros((n_samples, 1))
    return X, y

# %%
# create and save a plot of generated images (reversed grayscale)
def save_plot(examples, epoch, n=10):
    # plot images
    for i in range(n * n):
        # define subplot
        plt.subplot(n,n, 1+i)
        # turn off axis
        plt.axis('off')
        # plot raw pixel data
        plt.imshow(examples[i, :, :, 0],
                   cmap='gray_r')
     # save plot to file
    filename = 'results/GAN_Ae3/generated_2GAN_plot_e%04d.png' % (epoch+1)
    plt.savefig(filename)
    plt.close()

# %% [markdown]
# def calculate_fid(images_real, images_generated):
#     model = InceptionV3(include_top=False, pooling='avg', input_shape=(56, 56, 1))
#
#     images_real_resized = preprocess_input(images_real)
#     images_generated_resized = preprocess_input(images_generated)
#
#     features_real = model.predict(images_real_resized)
#     features_generated = model.predict(images_generated_resized)
#
#     mu_real, sigma_real = np.mean(features_real, axis=0), np.cov(features_real, rowvar=False)
#     mu_generated, sigma_generated = np.mean(features_generated, axis=0), np.cov(features_generated, rowvar=False)
#
#     sqrt_term, _ = sqrtm(sigma_real.dot(sigma_generated), disp=False)
#     if not np.isfinite(sqrt_term).all():
#         sqrt_term = np.real(sqrt_term)
#     fid = np.linalg.norm(mu_real - mu_generated) + np.trace(sigma_real + sigma_generated - 2 * sqrt_term)
#
#     return fid

# %%
def calculate_ssim(images_real, images_generated):
    ssim_scores = []

    for i in range(len(images_real)):
        
        # Desempaqueta las imágenes de un solo canal si es necesario
        img_real = np.squeeze(images_real[i])
        img_generated = np.squeeze(images_generated[i])

        # Calcula el SSIM entre las dos imágenes
        score, _ = ssim(img_real, img_generated, data_range=img_real.max() - img_real.min(), full=True)
        ssim_scores.append(score)

    average_ssim = np.mean(ssim_scores)
    
    return average_ssim

# %%
def compute_mmd(real_images, generated_images):
    # Aplanar las imágenes
    real_images_flat = real_images.reshape((len(real_images), -1))
    generated_images_flat = generated_images.reshape((len(generated_images), -1))

    # Calcular las matrices de distancia
    real_distances = pairwise_distances(real_images_flat, real_images_flat)
    generated_distances = pairwise_distances(generated_images_flat, generated_images_flat)
    cross_distances = pairwise_distances(real_images_flat, generated_images_flat)

    # Calcular las estimaciones del kernel
    real_kernel = np.mean(np.exp(-0.5 * real_distances**2))
    generated_kernel = np.mean(np.exp(-0.5 * generated_distances**2))
    cross_kernel = np.mean(np.exp(-0.5 * cross_distances**2))

    # Calcular la MMD
    mmd = real_kernel + generated_kernel - 2 * cross_kernel

    return mmd

# %%
def calculate_kde(images_set):
    # Aplanar y normalizar las imágenes
    flattened_images = images_set.reshape((len(images_set), -1))

    # Definir la Estimación de Densidad de Kernel (KDE)
    kde = KernelDensity(bandwidth=0.5)
    kde.fit(flattened_images)

    # Generar nuevos datos para evaluar la densidad de KDE
    num_samples = 1000
    samples = np.random.normal(0, 1, size=(num_samples, flattened_images.shape[1]))

    # Calcular la densidad de KDE en los nuevos datos
    log_density = kde.score_samples(samples)

    # Calcular la entropía de KDE
    entropy_value = -np.mean(log_density)

    return entropy_value

# %%
def coverage_metric(real_images, generated_images, k=5):
    # Aplanar las imágenes
    real_images_flat = real_images.reshape((len(real_images), -1))
    generated_images_flat = generated_images.reshape((len(generated_images), -1))

    # Entrenar un modelo de vecinos más cercanos en datos reales
    neighbors_real = NearestNeighbors(n_neighbors=k)
    neighbors_real.fit(real_images_flat)

    # Encontrar los k vecinos más cercanos de cada muestra generada en datos reales
    distances, _ = neighbors_real.kneighbors(generated_images_flat)

    # Calcular la métrica de cobertura como la fracción de muestras generadas que tienen vecinos en datos reales
    coverage = np.mean(np.min(distances, axis=1) <= 0.0)

    return coverage

# %%
# evaluate the discriminator, plot generated images, save generator model
def summarize_performance(epoch, g_model,dataset, latent_dim, n_samples=100):
   # generate samples
    x_fake, _ = generate_fake_samples(g_model, latent_dim, n_samples)
    x_real, _ = generate_real_samples_v2(n_samples)
    #evaluate model
    #print(x_fake.shape)
    ssim_score = calculate_ssim(x_real,x_fake)
    
    mmd_score = calculate_ssim(x_real,x_fake)
    
    coverage = coverage_metric(x_real,x_fake)
    
    fake_kde = calculate_kde(x_fake)
    real_kde = calculate_kde(x_real)
    #fid_score = calculate_ssim(x_real,x_fake)
    #print("fid:espera, ssim:{}".format(ssim_score))
    # save plot
    save_plot(x_fake, epoch)
    # save the generator model tile file
    #filename = 'results/GAN_Ae/models/generator_2D_model_%03d.h5' % (epoch + 1)
    #g_model.save(filename)
    return ssim_score,fake_kde,real_kde,mmd_score,coverage#,fid_score

# %%
# create a line plot of loss for the gan and save to file
def plot_history(d_hist, g_hist, a_hist):
    # plot loss
    #plt.subplot(2, 1, 1)
    plt.plot(d_hist, label='dis')
    plt.plot(g_hist, label='gen')
    plt.legend()
    # plot discriminator accuracy
    #plt.subplot(2, 1, 2)
    #plt.plot(a_hist, label='acc')
    #plt.legend()
    # save plot to file
    plt.savefig('results/GAN_Ae3/eval/plot_line_plot_loss.png')
    plt.close()

# %%
def plot_ssim(ssim):#,fid):
    
    plt.plot(ssim, label = 'ssim score')
    plt.legend()
    
    # save plot to file
    plt.savefig('results/GAN_Ae3/eval/plot_evaluation_ssim.png')
    plt.close()

# %%
def plot_coverage(coverage):#,fid):
    
    plt.plot(coverage, label = 'coverage')
    plt.legend()
    
    # save plot to file
    plt.savefig('results/GAN_Ae3/eval/plot_evaluation_coverage.png')
    plt.close()

# %%
def plot_mmd(mmd):#,fid):
    
    plt.plot(mmd, label = 'mmd score')
    plt.legend()
    
    # save plot to file
    plt.savefig('results/GAN_Ae3/eval/plot_evaluation_mmd.png')
    plt.close()

# %%
def plot_kde(rKde, fKde):#,fid):
    
    plt.plot(rKde, label = 'real KDE')
    plt.plot(fKde, label = 'fake KDE')
    plt.legend()
    
    # save plot to file
    plt.savefig('results/GAN_Ae3/eval/plot_evaluation_KDE.png')
    plt.close()

# %%
# train the generator and discriminator
def train(g_model, d_model, gan_model, dataset, latent_dim,
          n_epochs=10, n_batch=batch_size):
    # calculate the number of batches per epoch
    bat_per_epo = int(dataset.shape[0] / n_batch)
    # calculate the total iterations based on batch and epoch
    n_steps = bat_per_epo * n_epochs
    # calculate the number of samples in half a batch
    half_batch = int(n_batch / 2)
    
    # prepare lists for storing stats each iteration
    d_hist, g_hist, a_hist = list(), list(), list()
    
    #prepare lists for storing evaluation each iteration
    ssim,fkde,rkde,mmd,coverage = list(),list(),list(),list(),list()
    
# manually enumerate epochs
    for i in range(n_steps):
        # Train the discriminator 
        ## get randomly selected real samples
        X_real, y_real = generate_real_samples_v2(half_batch)
        # generate fake examples
        X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
        #print(X_real.shape,X_fake.shape)
        ## combine into one batch
        X, y = vstack((X_real, X_fake)), vstack((y_real, y_fake))
        # update discriminator model weights
        d_loss, d_acc = d_model.train_on_batch(X, y)
            
        #Train the generator
        # prepare points in latent space as input for the generator
        X_gan = generate_latent_points(latent_dim, n_batch)
        # create inverted labels for the fake samples
        y_gan = ones((n_batch, 1))
        # update the generator via the discriminator✬s error
        g_loss, _ = gan_model.train_on_batch(X_gan, y_gan)
           
        # summarize loss on this batch
        print('>%d, d=%.3f, g=%.3f, a=%d' % (i+1, d_loss, g_loss, int(100*d_acc)))
        # record history
        d_hist.append(d_loss)
        g_hist.append(g_loss)
        a_hist.append(d_acc)
        # evaluate the model performance every epoch
        if (i+1) % bat_per_epo == 0:
            ssimScore,fKDE,rKDE,mmdScore,cScore = summarize_performance(i, g_model, dataset, latent_dim)
            #epoch, g_model, d_model, dataset, latent_dim,
            ssim.append(ssimScore)
            fkde.append(fKDE)
            rkde.append(rKDE)
            mmd.append(mmdScore)
            coverage.append(cScore)
            #fid.append(b)
    plot_history(d_hist, g_hist, a_hist)
    plot_ssim(ssim)
    plot_kde(rkde,fkde)
    plot_mmd(mmd)
    plot_coverage(coverage)

# %%
#Make folder in dir
makedirs('results/GAN_Ae3', exist_ok=True)
makedirs('results/GAN_Ae3/eval', exist_ok=True)
# size of the latent space
latent_dim = 100
# create the discriminator
d_model = define_discriminator()
# create the
g_model = define_generator(latent_dim)
# create the gan
gan_model = define_gan(g_model, d_model)
# load image data
dataset = data_img
#dataset = load_real_samples()
# train model
train(g_model, d_model, gan_model, dataset, latent_dim)#,n_epochs=20)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 112, 112, 32)      320
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 112, 112, 32)      0
#
#  dropout_5 (Dropout)         (None, 112, 112, 32)      0
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 64)        18496
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 56, 56, 64)        0
#
#  dropout_6 (Dropout)         (None, 56, 56, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 64)        36928
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  dropout_7 (Dropout)         (None, 28, 28, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 128)       73856
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  dropout_8 (Dropout)         (None, 14, 14, 128)       0
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 128)         147584
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 7, 7, 128)         0
#
#  dropout_9 (Dropout)         (None, 7, 7, 128)         0
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_3 (Dense)             (None, 4096)              25694208
#
#  dense_4 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 25,975,489
# Trainable params: 25,975,489
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 12544)             1266944
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 12544)             0
#
#  reshape_1 (Reshape)         (None, 7, 7, 256)         0
#
#  conv2d_transpose_5 (Conv2DT  (None, 14, 14, 128)      295040
#  ranspose)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 14, 14, 128)       0
#
#  conv2d_transpose_6 (Conv2DT  (None, 28, 28, 64)       73792
#  ranspose)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 28, 28, 64)        0
#
#  conv2d_transpose_7 (Conv2DT  (None, 56, 56, 32)       18464
#  ranspose)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 56, 56, 32)        0
#
#  conv2d_transpose_8 (Conv2DT  (None, 112, 112, 16)     4624
#  ranspose)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 112, 112, 16)      0
#
#  conv2d_transpose_9 (Conv2DT  (None, 224, 224, 16)     2320
#  ranspose)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 224, 224, 16)      0
#
#  conv2d_11 (Conv2D)          (None, 224, 224, 1)       785
#
# =================================================================
# Total params: 1,661,969
# Trainable params: 1,661,969
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 224, 224, 1)       1661969
#
#  sequential_3 (Sequential)   (None, 1)                 25975489
#
# =================================================================
# Total params: 27,637,458
# Trainable params: 1,661,969
# Non-trainable params: 25,975,489
# _________________________________________________________________
# 1/1 [==============================] - 0s 120ms/step
# >1, d=0.687, g=0.676, a=62
# 1/1 [==============================] - 0s 17ms/step
# >2, d=0.645, g=0.681, a=53
# 1/1 [==============================] - 0s 16ms/step
# >3, d=0.580, g=0.744, a=75
# 1/1 [==============================] - 0s 6ms/step
# >4, d=0.501, g=0.924, a=93
# 1/1 [==============================] - 0s 21ms/step
# >5, d=0.399, g=1.337, a=100
# 1/1 [==============================] - 0s 3ms/step
# >6, d=0.233, g=2.305, a=100
# 1/1 [==============================] - 0s 16ms/step
# >7, d=0.104, g=3.439, a=100
# 1/1 [==============================] - 0s 3ms/step
# >8, d=0.027, g=4.557, a=100
# 1/1 [==============================] - 0s 32ms/step
# >9, d=0.015, g=4.998, a=100
# 1/1 [==============================] - 0s 6ms/step
# >10, d=0.004, g=5.822, a=100
# 1/1 [==============================] - 0s 32ms/step
# >11, d=0.002, g=6.525, a=100
# 1/1 [==============================] - 0s 7ms/step
# >12, d=0.001, g=7.039, a=100
# 1/1 [==============================] - 0s 16ms/step
# >13, d=0.001, g=7.484, a=100
# 1/1 [==============================] - 0s 5ms/step
# >14, d=0.000, g=7.452, a=100
# 1/1 [==============================] - 0s 19ms/step
# >15, d=0.000, g=7.711, a=100
# 1/1 [==============================] - 0s 16ms/step
# >16, d=0.002, g=7.228, a=100
# 1/1 [==============================] - 0s 5ms/step
# >17, d=0.001, g=7.226, a=100
# 1/1 [==============================] - 0s 21ms/step
# >18, d=0.001, g=7.143, a=100
# 1/1 [==============================] - 0s 16ms/step
# >19, d=0.001, g=7.431, a=100
# 1/1 [==============================] - 0s 17ms/step
# >20, d=0.000, g=7.461, a=100
# 1/1 [==============================] - 0s 17ms/step
# >21, d=0.001, g=7.366, a=100
# 1/1 [==============================] - 0s 28ms/step
# >22, d=0.000, g=7.073, a=100
# 1/1 [==============================] - 0s 4ms/step
# >23, d=0.001, g=7.169, a=100
# 1/1 [==============================] - 0s 16ms/step
# >24, d=0.001, g=6.980, a=100
# 1/1 [==============================] - 0s 4ms/step
# >25, d=0.002, g=6.727, a=100
# 1/1 [==============================] - 0s 16ms/step
# >26, d=0.003, g=6.632, a=100
# 1/1 [==============================] - 0s 17ms/step
# >27, d=0.003, g=6.808, a=100
# 1/1 [==============================] - 0s 16ms/step
# >28, d=0.009, g=5.294, a=100
# 1/1 [==============================] - 0s 19ms/step
# >29, d=0.030, g=4.048, a=100
# 1/1 [==============================] - 0s 2ms/step
# >30, d=0.100, g=7.960, a=96
# 1/1 [==============================] - 0s 16ms/step
# >31, d=1.503, g=0.504, a=78
# 1/1 [==============================] - 0s 17ms/step
# >32, d=0.448, g=0.550, a=71
# 1/1 [==============================] - 0s 18ms/step
# >33, d=0.665, g=0.728, a=56
# 1/1 [==============================] - 0s 6ms/step
# >34, d=0.369, g=1.081, a=84
# 1/1 [==============================] - 0s 16ms/step
# >35, d=0.212, g=1.382, a=96
# 1/1 [==============================] - 0s 28ms/step
# >36, d=0.172, g=1.571, a=100
# 1/1 [==============================] - 0s 17ms/step
# >37, d=0.119, g=1.943, a=100
# 1/1 [==============================] - 0s 16ms/step
# >38, d=0.099, g=2.258, a=100
# 1/1 [==============================] - 0s 16ms/step
# >39, d=0.079, g=2.487, a=100
# 1/1 [==============================] - 0s 6ms/step
# >40, d=0.054, g=2.770, a=100
# 1/1 [==============================] - 0s 16ms/step
# >41, d=0.045, g=2.982, a=100
# 1/1 [==============================] - 0s 22ms/step
# >42, d=0.039, g=3.155, a=100
# 1/1 [==============================] - 0s 16ms/step
# >43, d=0.024, g=3.420, a=100
# 1/1 [==============================] - 0s 20ms/step
# >44, d=0.046, g=3.266, a=100
# 1/1 [==============================] - 0s 29ms/step
# >45, d=0.027, g=3.306, a=100
# 1/1 [==============================] - 0s 5ms/step
# >46, d=0.020, g=3.416, a=100
# 1/1 [==============================] - 0s 9ms/step
# >47, d=0.018, g=3.464, a=100
# 1/1 [==============================] - 0s 13ms/step
# >48, d=0.024, g=3.627, a=100
# 1/1 [==============================] - 0s 7ms/step
# >49, d=0.030, g=3.713, a=100
# 1/1 [==============================] - 0s 21ms/step
# >50, d=0.036, g=4.066, a=100
# 1/1 [==============================] - 0s 19ms/step
# >51, d=0.011, g=4.407, a=100
# 1/1 [==============================] - 0s 18ms/step
# >52, d=0.010, g=4.446, a=100
# 1/1 [==============================] - 0s 17ms/step
# >53, d=0.009, g=4.619, a=100
# 1/1 [==============================] - 0s 3ms/step
# >54, d=0.006, g=4.725, a=100
# 1/1 [==============================] - 0s 16ms/step
# >55, d=0.012, g=4.217, a=100
# 1/1 [==============================] - 0s 15ms/step
# >56, d=0.013, g=4.650, a=100
# 1/1 [==============================] - 0s 15ms/step
# >57, d=0.027, g=5.109, a=100
# 1/1 [==============================] - 0s 29ms/step
# >58, d=0.005, g=5.395, a=100
# 1/1 [==============================] - 0s 31ms/step
# >59, d=0.005, g=5.183, a=100
# 1/1 [==============================] - 0s 16ms/step
# >60, d=0.004, g=5.422, a=100
# 1/1 [==============================] - 0s 7ms/step
# >61, d=0.003, g=5.248, a=100
# 1/1 [==============================] - 0s 16ms/step
# >62, d=0.006, g=5.518, a=100
# 1/1 [==============================] - 0s 4ms/step
# >63, d=0.005, g=5.713, a=100
# 1/1 [==============================] - 0s 24ms/step
# >64, d=0.020, g=5.113, a=100
# 1/1 [==============================] - 0s 3ms/step
# >65, d=0.035, g=5.489, a=96
# 1/1 [==============================] - 0s 8ms/step
# >66, d=0.002, g=5.672, a=100
# 1/1 [==============================] - 0s 28ms/step
# >67, d=0.004, g=5.752, a=100
# 1/1 [==============================] - 0s 16ms/step
# >68, d=0.002, g=5.850, a=100
# 1/1 [==============================] - 0s 31ms/step
# >69, d=0.002, g=5.789, a=100
# 1/1 [==============================] - 0s 10ms/step
# >70, d=0.006, g=5.709, a=100
# 1/1 [==============================] - 0s 16ms/step
# >71, d=0.002, g=5.819, a=100
# 1/1 [==============================] - 0s 29ms/step
# >72, d=0.007, g=6.367, a=100
# 1/1 [==============================] - 0s 30ms/step
# >73, d=0.020, g=6.578, a=100
# 1/1 [==============================] - 0s 23ms/step
# >74, d=0.007, g=7.006, a=100
# 1/1 [==============================] - 0s 16ms/step
# >75, d=0.003, g=6.629, a=100
# 1/1 [==============================] - 0s 18ms/step
# >76, d=0.002, g=6.678, a=100
# 1/1 [==============================] - 0s 16ms/step
# >77, d=0.001, g=6.295, a=100
# 1/1 [==============================] - 0s 33ms/step
# >78, d=0.072, g=5.188, a=93
# 1/1 [==============================] - 0s 16ms/step
# >79, d=0.004, g=5.116, a=100
# 1/1 [==============================] - 0s 16ms/step
# >80, d=0.006, g=4.980, a=100
# 1/1 [==============================] - 0s 16ms/step
# >81, d=0.032, g=6.681, a=100
# 1/1 [==============================] - 0s 19ms/step
# >82, d=0.001, g=6.780, a=100
# 1/1 [==============================] - 0s 19ms/step
# >83, d=0.005, g=7.605, a=100
# 1/1 [==============================] - 0s 16ms/step
# >84, d=0.000, g=8.083, a=100
# 1/1 [==============================] - 0s 16ms/step
# >85, d=0.029, g=4.511, a=100
# 1/1 [==============================] - 0s 19ms/step
# >86, d=0.165, g=7.588, a=93
# 1/1 [==============================] - 0s 34ms/step
# >87, d=0.006, g=8.282, a=100
# 1/1 [==============================] - 0s 14ms/step
# >88, d=0.023, g=6.938, a=100
# 1/1 [==============================] - 0s 23ms/step
# >89, d=0.002, g=6.619, a=100
# 1/1 [==============================] - 0s 16ms/step
# >90, d=0.011, g=6.726, a=100
# 1/1 [==============================] - 0s 26ms/step
# >91, d=0.002, g=6.633, a=100
# 1/1 [==============================] - 0s 4ms/step
# >92, d=0.011, g=6.447, a=100
# 1/1 [==============================] - 0s 16ms/step
# >93, d=0.223, g=9.618, a=93
# 1/1 [==============================] - 0s 5ms/step
# >94, d=1.009, g=0.938, a=56
# 1/1 [==============================] - 0s 31ms/step
# >95, d=2.156, g=1.412, a=71
# 1/1 [==============================] - 0s 16ms/step
# >96, d=0.600, g=1.875, a=84
# 1/1 [==============================] - 0s 33ms/step
# >97, d=0.253, g=2.713, a=93
# 1/1 [==============================] - 0s 22ms/step
# >98, d=0.056, g=3.216, a=100
# 1/1 [==============================] - 0s 16ms/step
# >99, d=0.050, g=3.398, a=100
# 1/1 [==============================] - 0s 33ms/step
# >100, d=0.053, g=3.479, a=100
# 1/1 [==============================] - 0s 16ms/step
# >101, d=0.055, g=3.461, a=100
# 1/1 [==============================] - 0s 30ms/step
# >102, d=0.047, g=3.641, a=100
# 1/1 [==============================] - 0s 19ms/step
# >103, d=0.045, g=3.558, a=100
# 1/1 [==============================] - 0s 17ms/step
# >104, d=0.021, g=3.754, a=100
# 1/1 [==============================] - 0s 7ms/step
# >105, d=0.036, g=3.535, a=100
# 1/1 [==============================] - 0s 15ms/step
# >106, d=0.023, g=3.678, a=100
# 1/1 [==============================] - 0s 32ms/step
# >107, d=0.202, g=3.817, a=93
# 1/1 [==============================] - 0s 19ms/step
# >108, d=0.029, g=3.000, a=100
# 1/1 [==============================] - 0s 25ms/step
# >109, d=0.066, g=3.409, a=100
# 1/1 [==============================] - 0s 16ms/step
# >110, d=0.068, g=3.775, a=96
# 1/1 [==============================] - 0s 20ms/step
# >111, d=0.055, g=4.320, a=100
# 1/1 [==============================] - 0s 16ms/step
# >112, d=0.030, g=3.963, a=100
# 1/1 [==============================] - 0s 16ms/step
# >113, d=0.015, g=4.202, a=100
# 1/1 [==============================] - 0s 33ms/step
# >114, d=0.037, g=4.494, a=100
# 1/1 [==============================] - 0s 16ms/step
# >115, d=0.011, g=4.395, a=100
# 1/1 [==============================] - 0s 4ms/step
# >116, d=0.017, g=3.843, a=100
# 1/1 [==============================] - 0s 32ms/step
# >117, d=0.016, g=4.152, a=100
# 1/1 [==============================] - 0s 31ms/step
# >118, d=0.018, g=4.641, a=100
# 1/1 [==============================] - 0s 6ms/step
# >119, d=0.044, g=4.859, a=96
# 1/1 [==============================] - 0s 29ms/step
# >120, d=0.014, g=4.357, a=100
# 1/1 [==============================] - 0s 16ms/step
# >121, d=0.017, g=5.154, a=100
# 1/1 [==============================] - 0s 16ms/step
# >122, d=0.023, g=5.327, a=100
# 1/1 [==============================] - 0s 2ms/step
# >123, d=0.032, g=5.123, a=100
# 1/1 [==============================] - 0s 27ms/step
# >124, d=0.142, g=4.483, a=93
# 1/1 [==============================] - 0s 20ms/step
# >125, d=0.031, g=4.125, a=100
# 1/1 [==============================] - 0s 16ms/step
# >126, d=0.057, g=4.827, a=100
# 1/1 [==============================] - 0s 15ms/step
# >127, d=0.045, g=5.673, a=100
# 1/1 [==============================] - 0s 18ms/step
# >128, d=0.039, g=5.827, a=100
# 1/1 [==============================] - 0s 3ms/step
# >129, d=0.022, g=5.754, a=100
# 1/1 [==============================] - 0s 30ms/step
# >130, d=0.089, g=4.481, a=96
# 1/1 [==============================] - 0s 29ms/step
# >131, d=0.086, g=4.870, a=93
# 1/1 [==============================] - 0s 24ms/step
# >132, d=0.083, g=6.199, a=96
# 1/1 [==============================] - 0s 16ms/step
# >133, d=0.152, g=5.126, a=93
# 1/1 [==============================] - 0s 16ms/step
# >134, d=0.055, g=4.027, a=100
# 1/1 [==============================] - 0s 29ms/step
# >135, d=0.076, g=5.513, a=96
# 1/1 [==============================] - 0s 16ms/step
# >136, d=0.011, g=5.490, a=100
# 1/1 [==============================] - 0s 19ms/step
# >137, d=0.022, g=4.733, a=100
# 1/1 [==============================] - 0s 28ms/step
# >138, d=0.021, g=5.784, a=100
# 1/1 [==============================] - 0s 7ms/step
# >139, d=0.022, g=5.086, a=100
# 1/1 [==============================] - 0s 31ms/step
# >140, d=0.053, g=4.436, a=96
# 1/1 [==============================] - 0s 16ms/step
# >141, d=0.071, g=5.325, a=100
# 1/1 [==============================] - 0s 26ms/step
# >142, d=0.029, g=6.235, a=100
# 1/1 [==============================] - 0s 4ms/step
# >143, d=0.051, g=5.962, a=100
# 1/1 [==============================] - 0s 30ms/step
# >144, d=0.018, g=5.489, a=100
# 1/1 [==============================] - 0s 10ms/step
# >145, d=0.189, g=4.170, a=96
# 1/1 [==============================] - 0s 16ms/step
# >146, d=0.148, g=5.064, a=90
# 1/1 [==============================] - 0s 16ms/step
# >147, d=0.020, g=6.675, a=100
# 1/1 [==============================] - 0s 16ms/step
# >148, d=0.033, g=5.647, a=100
# 1/1 [==============================] - 0s 5ms/step
# >149, d=0.136, g=4.137, a=96
# 1/1 [==============================] - 0s 35ms/step
# >150, d=0.077, g=5.336, a=100
# 1/1 [==============================] - 0s 1000us/step
# >151, d=0.058, g=6.861, a=100
# 1/1 [==============================] - 0s 8ms/step
# >152, d=0.100, g=5.388, a=96
# 1/1 [==============================] - 0s 9ms/step
# >153, d=0.041, g=5.326, a=100
# 1/1 [==============================] - 0s 17ms/step
# >154, d=0.192, g=8.405, a=87
# 1/1 [==============================] - 0s 24ms/step
# >155, d=0.994, g=0.810, a=59
# 1/1 [==============================] - 0s 24ms/step
# >156, d=2.208, g=2.573, a=62
# 1/1 [==============================] - 0s 29ms/step
# >157, d=0.144, g=5.353, a=100
# 1/1 [==============================] - 0s 4ms/step
# >158, d=0.122, g=4.780, a=96
# 1/1 [==============================] - 0s 29ms/step
# >159, d=0.224, g=2.663, a=84
# 1/1 [==============================] - 0s 5ms/step
# >160, d=0.057, g=2.166, a=100
# 1/1 [==============================] - 0s 27ms/step
# >161, d=0.117, g=2.522, a=93
# 1/1 [==============================] - 0s 16ms/step
# >162, d=0.117, g=3.390, a=100
# 4/4 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 16ms/step
# >163, d=0.038, g=3.863, a=100
# 1/1 [==============================] - 0s 16ms/step
# >164, d=0.056, g=4.134, a=100
# 1/1 [==============================] - 0s 31ms/step
# >165, d=0.059, g=3.769, a=100
# 1/1 [==============================] - 0s 16ms/step
# >166, d=0.038, g=3.086, a=100
# 1/1 [==============================] - 0s 16ms/step
# >167, d=0.043, g=3.869, a=100
# 1/1 [==============================] - 0s 16ms/step
# >168, d=0.135, g=3.030, a=96
# 1/1 [==============================] - 0s 16ms/step
# >169, d=0.051, g=3.200, a=100
# 1/1 [==============================] - 0s 16ms/step
# >170, d=0.095, g=3.878, a=100
# 1/1 [==============================] - 0s 16ms/step
# >171, d=0.055, g=4.075, a=100
# 1/1 [==============================] - 0s 31ms/step
# >172, d=0.176, g=2.199, a=93
# 1/1 [==============================] - 0s 16ms/step
# >173, d=0.276, g=5.031, a=81
# 1/1 [==============================] - 0s 16ms/step
# >174, d=0.223, g=2.125, a=87
# 1/1 [==============================] - 0s 16ms/step
# >175, d=0.299, g=4.804, a=87
# 1/1 [==============================] - 0s 16ms/step
# >176, d=0.212, g=2.836, a=93
# 1/1 [==============================] - 0s 16ms/step
# >177, d=0.160, g=1.799, a=87
# 1/1 [==============================] - 0s 16ms/step
# >178, d=0.361, g=6.939, a=87
# 1/1 [==============================] - 0s 16ms/step
# >179, d=0.834, g=0.672, a=71
# 1/1 [==============================] - 0s 31ms/step
# >180, d=0.813, g=4.226, a=65
# 1/1 [==============================] - 0s 16ms/step
# >181, d=0.201, g=3.611, a=90
# 1/1 [==============================] - 0s 16ms/step
# >182, d=0.212, g=2.220, a=90
# 1/1 [==============================] - 0s 16ms/step
# >183, d=0.198, g=2.752, a=90
# 1/1 [==============================] - 0s 16ms/step
# >184, d=0.094, g=3.433, a=100
# 1/1 [==============================] - 0s 16ms/step
# >185, d=0.212, g=2.957, a=93
# 1/1 [==============================] - 0s 20ms/step
# >186, d=0.219, g=3.319, a=87
# 1/1 [==============================] - 0s 16ms/step
# >187, d=0.242, g=1.376, a=90
# 1/1 [==============================] - 0s 16ms/step
# >188, d=0.399, g=5.047, a=75
# 1/1 [==============================] - 0s 16ms/step
# >189, d=0.439, g=1.880, a=81
# 1/1 [==============================] - 0s 18ms/step
# >190, d=0.174, g=1.885, a=93
# 1/1 [==============================] - 0s 2ms/step
# >191, d=0.219, g=3.148, a=93
# 1/1 [==============================] - 0s 16ms/step
# >192, d=0.168, g=3.198, a=93
# 1/1 [==============================] - 0s 5ms/step
# >193, d=0.235, g=1.518, a=90
# 1/1 [==============================] - 0s 16ms/step
# >194, d=0.210, g=3.077, a=93
# 1/1 [==============================] - 0s 6ms/step
# >195, d=0.318, g=1.719, a=90
# 1/1 [==============================] - 0s 16ms/step
# >196, d=0.317, g=3.894, a=78
# 1/1 [==============================] - 0s 16ms/step
# >197, d=0.200, g=3.258, a=93
# 1/1 [==============================] - 0s 16ms/step
# >198, d=0.284, g=1.522, a=87
# 1/1 [==============================] - 0s 16ms/step
# >199, d=0.433, g=3.188, a=81
# 1/1 [==============================] - 0s 31ms/step
# >200, d=0.443, g=0.672, a=75
# 1/1 [==============================] - 0s 15ms/step
# >201, d=0.811, g=5.424, a=62
# 1/1 [==============================] - 0s 15ms/step
# >202, d=1.071, g=1.671, a=56
# 1/1 [==============================] - 0s 38ms/step
# >203, d=0.234, g=1.280, a=90
# 1/1 [==============================] - 0s 22ms/step
# >204, d=0.460, g=3.137, a=71
# 1/1 [==============================] - 0s 16ms/step
# >205, d=0.586, g=1.808, a=75
# 1/1 [==============================] - 0s 19ms/step
# >206, d=0.280, g=1.495, a=90
# 1/1 [==============================] - 0s 32ms/step
# >207, d=0.357, g=1.637, a=84
# 1/1 [==============================] - 0s 24ms/step
# >208, d=0.295, g=2.450, a=90
# 1/1 [==============================] - 0s 15ms/step
# >209, d=0.295, g=2.681, a=87
# 1/1 [==============================] - 0s 8ms/step
# >210, d=0.394, g=1.887, a=81
# 1/1 [==============================] - 0s 29ms/step
# >211, d=0.242, g=2.146, a=93
# 1/1 [==============================] - 0s 4ms/step
# >212, d=0.329, g=2.203, a=90
# 1/1 [==============================] - 0s 31ms/step
# >213, d=0.309, g=2.565, a=87
# 1/1 [==============================] - 0s 2ms/step
# >214, d=0.343, g=1.893, a=87
# 1/1 [==============================] - 0s 30ms/step
# >215, d=0.415, g=2.015, a=84
# 1/1 [==============================] - 0s 6ms/step
# >216, d=0.442, g=2.050, a=81
# 1/1 [==============================] - 0s 30ms/step
# >217, d=0.543, g=1.301, a=71
# 1/1 [==============================] - 0s 5ms/step
# >218, d=0.356, g=1.899, a=84
# 1/1 [==============================] - 0s 27ms/step
# >219, d=0.431, g=2.599, a=71
# 1/1 [==============================] - 0s 19ms/step
# >220, d=0.447, g=1.727, a=84
# 1/1 [==============================] - 0s 33ms/step
# >221, d=0.364, g=1.188, a=84
# 1/1 [==============================] - 0s 18ms/step
# >222, d=0.402, g=1.607, a=81
# 1/1 [==============================] - 0s 16ms/step
# >223, d=0.494, g=1.549, a=78
# 1/1 [==============================] - 0s 19ms/step
# >224, d=0.498, g=0.910, a=68
# 1/1 [==============================] - 0s 1ms/step
# >225, d=0.810, g=1.614, a=68
# 1/1 [==============================] - 0s 33ms/step
# >226, d=0.420, g=1.833, a=78
# 1/1 [==============================] - 0s 22ms/step
# >227, d=0.755, g=0.957, a=65
# 1/1 [==============================] - 0s 14ms/step
# >228, d=0.460, g=1.226, a=81
# 1/1 [==============================] - 0s 10ms/step
# >229, d=0.589, g=1.420, a=71
# 1/1 [==============================] - 0s 26ms/step
# >230, d=0.477, g=1.286, a=71
# 1/1 [==============================] - 0s 17ms/step
# >231, d=0.624, g=1.902, a=71
# 1/1 [==============================] - 0s 11ms/step
# >232, d=0.520, g=1.107, a=75
# 1/1 [==============================] - 0s 10ms/step
# >233, d=0.458, g=1.302, a=75
# 1/1 [==============================] - 0s 23ms/step
# >234, d=0.624, g=1.466, a=62
# 1/1 [==============================] - 0s 13ms/step
# >235, d=0.436, g=1.576, a=75
# 1/1 [==============================] - 0s 20ms/step
# >236, d=0.661, g=1.126, a=62
# 1/1 [==============================] - 0s 16ms/step
# >237, d=0.588, g=1.477, a=59
# 1/1 [==============================] - 0s 7ms/step
# >238, d=0.413, g=1.148, a=84
# 1/1 [==============================] - 0s 20ms/step
# >239, d=0.540, g=1.560, a=68
# 1/1 [==============================] - 0s 16ms/step
# >240, d=0.606, g=1.313, a=65
# 1/1 [==============================] - 0s 9ms/step
# >241, d=0.675, g=1.085, a=50
# 1/1 [==============================] - 0s 21ms/step
# >242, d=0.569, g=0.852, a=75
# 1/1 [==============================] - 0s 8ms/step
# >243, d=0.571, g=0.891, a=75
# 1/1 [==============================] - 0s 28ms/step
# >244, d=0.469, g=1.293, a=81
# 1/1 [==============================] - 0s 22ms/step
# >245, d=0.550, g=1.319, a=78
# 1/1 [==============================] - 0s 16ms/step
# >246, d=0.535, g=1.022, a=78
# 1/1 [==============================] - 0s 18ms/step
# >247, d=0.550, g=1.048, a=71
# 1/1 [==============================] - 0s 21ms/step
# >248, d=0.485, g=1.163, a=75
# 1/1 [==============================] - 0s 15ms/step
# >249, d=0.620, g=1.122, a=65
# 1/1 [==============================] - 0s 16ms/step
# >250, d=0.607, g=1.375, a=65
# 1/1 [==============================] - 0s 7ms/step
# >251, d=0.681, g=0.954, a=53
# 1/1 [==============================] - 0s 21ms/step
# >252, d=0.564, g=1.058, a=68
# 1/1 [==============================] - 0s 7ms/step
# >253, d=0.691, g=1.028, a=46
# 1/1 [==============================] - 0s 23ms/step
# >254, d=0.450, g=1.289, a=75
# 1/1 [==============================] - 0s 2ms/step
# >255, d=0.553, g=0.899, a=71
# 1/1 [==============================] - 0s 17ms/step
# >256, d=0.590, g=0.872, a=75
# 1/1 [==============================] - 0s 19ms/step
# >257, d=0.585, g=1.187, a=59
# 1/1 [==============================] - 0s 26ms/step
# >258, d=0.704, g=1.287, a=56
# 1/1 [==============================] - 0s 18ms/step
# >259, d=0.570, g=1.325, a=68
# 1/1 [==============================] - 0s 9ms/step
# >260, d=0.641, g=0.887, a=65
# 1/1 [==============================] - 0s 26ms/step
# >261, d=0.618, g=0.924, a=62
# 1/1 [==============================] - 0s 17ms/step
# >262, d=0.635, g=0.891, a=59
# 1/1 [==============================] - 0s 19ms/step
# >263, d=0.566, g=1.016, a=71
# 1/1 [==============================] - 0s 3ms/step
# >264, d=0.858, g=1.453, a=40
# 1/1 [==============================] - 0s 16ms/step
# >265, d=0.689, g=1.167, a=65
# 1/1 [==============================] - 0s 16ms/step
# >266, d=0.654, g=0.786, a=71
# 1/1 [==============================] - 0s 20ms/step
# >267, d=0.594, g=0.923, a=71
# 1/1 [==============================] - 0s 16ms/step
# >268, d=0.553, g=1.104, a=65
# 1/1 [==============================] - 0s 16ms/step
# >269, d=0.672, g=1.110, a=59
# 1/1 [==============================] - 0s 27ms/step
# >270, d=0.576, g=0.709, a=68
# 1/1 [==============================] - 0s 18ms/step
# >271, d=0.554, g=0.782, a=68
# 1/1 [==============================] - 0s 16ms/step
# >272, d=0.642, g=0.886, a=65
# 1/1 [==============================] - 0s 26ms/step
# >273, d=0.690, g=0.880, a=53
# 1/1 [==============================] - 0s 16ms/step
# >274, d=0.635, g=0.782, a=68
# 1/1 [==============================] - 0s 16ms/step
# >275, d=0.559, g=0.956, a=75
# 1/1 [==============================] - 0s 16ms/step
# >276, d=0.577, g=1.085, a=75
# 1/1 [==============================] - 0s 15ms/step
# >277, d=0.654, g=0.845, a=59
# 1/1 [==============================] - 0s 16ms/step
# >278, d=0.715, g=1.230, a=62
# 1/1 [==============================] - 0s 16ms/step
# >279, d=0.596, g=0.919, a=68
# 1/1 [==============================] - 0s 24ms/step
# >280, d=0.520, g=1.086, a=81
# 1/1 [==============================] - 0s 24ms/step
# >281, d=0.594, g=0.752, a=71
# 1/1 [==============================] - 0s 6ms/step
# >282, d=0.599, g=0.813, a=71
# 1/1 [==============================] - 0s 31ms/step
# >283, d=0.616, g=1.068, a=65
# 1/1 [==============================] - 0s 9ms/step
# >284, d=0.561, g=0.851, a=75
# 1/1 [==============================] - 0s 26ms/step
# >285, d=0.659, g=0.861, a=59
# 1/1 [==============================] - 0s 5ms/step
# >286, d=0.493, g=1.063, a=81
# 1/1 [==============================] - 0s 16ms/step
# >287, d=0.592, g=0.813, a=71
# 1/1 [==============================] - 0s 27ms/step
# >288, d=0.581, g=1.279, a=65
# 1/1 [==============================] - 0s 24ms/step
# >289, d=0.594, g=0.888, a=71
# 1/1 [==============================] - 0s 16ms/step
# >290, d=0.553, g=0.909, a=75
# 1/1 [==============================] - 0s 27ms/step
# >291, d=0.599, g=1.198, a=71
# 1/1 [==============================] - 0s 16ms/step
# >292, d=0.540, g=1.114, a=68
# 1/1 [==============================] - 0s 16ms/step
# >293, d=0.635, g=0.683, a=56
# 1/1 [==============================] - 0s 16ms/step
# >294, d=0.566, g=0.951, a=71
# 1/1 [==============================] - 0s 18ms/step
# >295, d=0.541, g=1.166, a=78
# 1/1 [==============================] - 0s 18ms/step
# >296, d=0.559, g=0.805, a=68
# 1/1 [==============================] - 0s 16ms/step
# >297, d=0.529, g=1.008, a=78
# 1/1 [==============================] - 0s 32ms/step
# >298, d=0.577, g=1.111, a=68
# 1/1 [==============================] - 0s 24ms/step
# >299, d=0.506, g=0.924, a=71
# 1/1 [==============================] - 0s 972us/step
# >300, d=0.516, g=1.268, a=81
# 1/1 [==============================] - 0s 16ms/step
# >301, d=0.464, g=0.868, a=84
# 1/1 [==============================] - 0s 28ms/step
# >302, d=0.595, g=1.532, a=65
# 1/1 [==============================] - 0s 8ms/step
# >303, d=0.497, g=0.783, a=68
# 1/1 [==============================] - 0s 16ms/step
# >304, d=0.500, g=1.458, a=87
# 1/1 [==============================] - 0s 19ms/step
# >305, d=0.481, g=0.680, a=84
# 1/1 [==============================] - 0s 18ms/step
# >306, d=0.583, g=1.993, a=65
# 1/1 [==============================] - 0s 7ms/step
# >307, d=0.670, g=0.743, a=62
# 1/1 [==============================] - 0s 4ms/step
# >308, d=0.573, g=1.329, a=65
# 1/1 [==============================] - 0s 29ms/step
# >309, d=0.574, g=0.759, a=75
# 1/1 [==============================] - 0s 24ms/step
# >310, d=0.705, g=1.307, a=56
# 1/1 [==============================] - 0s 5ms/step
# >311, d=0.583, g=0.819, a=71
# 1/1 [==============================] - 0s 25ms/step
# >312, d=0.549, g=1.195, a=68
# 1/1 [==============================] - 0s 9ms/step
# >313, d=0.493, g=0.986, a=81
# 1/1 [==============================] - 0s 31ms/step
# >314, d=0.621, g=1.073, a=65
# 1/1 [==============================] - 0s 17ms/step
# >315, d=0.552, g=1.359, a=71
# 1/1 [==============================] - 0s 18ms/step
# >316, d=0.680, g=0.718, a=56
# 1/1 [==============================] - 0s 10ms/step
# >317, d=0.622, g=1.167, a=59
# 1/1 [==============================] - 0s 16ms/step
# >318, d=0.510, g=1.304, a=81
# 1/1 [==============================] - 0s 25ms/step
# >319, d=0.649, g=0.829, a=62
# 1/1 [==============================] - 0s 16ms/step
# >320, d=0.657, g=1.225, a=59
# 1/1 [==============================] - 0s 16ms/step
# >321, d=0.610, g=0.971, a=68
# 1/1 [==============================] - 0s 23ms/step
# >322, d=0.591, g=0.811, a=65
# 1/1 [==============================] - 0s 11ms/step
# >323, d=0.503, g=1.337, a=81
# 1/1 [==============================] - 0s 29ms/step
# >324, d=0.558, g=0.724, a=71
# 4/4 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# >325, d=0.577, g=1.566, a=65
# 1/1 [==============================] - 0s 11ms/step
# >326, d=0.682, g=1.101, a=56
# 1/1 [==============================] - 0s 22ms/step
# >327, d=0.520, g=1.134, a=84
# 1/1 [==============================] - 0s 19ms/step
# >328, d=0.602, g=1.102, a=71
# 1/1 [==============================] - 0s 4ms/step
# >329, d=0.584, g=0.747, a=84
# 1/1 [==============================] - 0s 19ms/step
# >330, d=0.640, g=1.147, a=62
# 1/1 [==============================] - 0s 18ms/step
# >331, d=0.515, g=1.625, a=84
# 1/1 [==============================] - 0s 10ms/step
# >332, d=0.564, g=0.937, a=75
# 1/1 [==============================] - 0s 20ms/step
# >333, d=0.681, g=0.906, a=68
# 1/1 [==============================] - 0s 20ms/step
# >334, d=0.378, g=1.348, a=84
# 1/1 [==============================] - 0s 18ms/step
# >335, d=0.433, g=1.116, a=84
# 1/1 [==============================] - 0s 21ms/step
# >336, d=0.455, g=1.095, a=84
# 1/1 [==============================] - 0s 29ms/step
# >337, d=0.728, g=0.891, a=62
# 1/1 [==============================] - 0s 24ms/step
# >338, d=0.476, g=1.487, a=78
# 1/1 [==============================] - 0s 31ms/step
# >339, d=0.491, g=1.194, a=75
# 1/1 [==============================] - 0s 20ms/step
# >340, d=0.706, g=1.168, a=62
# 1/1 [==============================] - 0s 16ms/step
# >341, d=0.686, g=1.054, a=56
# 1/1 [==============================] - 0s 16ms/step
# >342, d=0.559, g=0.630, a=71
# 1/1 [==============================] - 0s 16ms/step
# >343, d=0.678, g=1.245, a=59
# 1/1 [==============================] - 0s 15ms/step
# >344, d=0.544, g=1.617, a=71
# 1/1 [==============================] - 0s 1ms/step
# >345, d=0.691, g=0.730, a=65
# 1/1 [==============================] - 0s 16ms/step
# >346, d=0.590, g=0.875, a=65
# 1/1 [==============================] - 0s 34ms/step
# >347, d=0.665, g=0.883, a=56
# 1/1 [==============================] - 0s 16ms/step
# >348, d=0.788, g=1.399, a=56
# 1/1 [==============================] - 0s 16ms/step
# >349, d=0.665, g=0.942, a=68
# 1/1 [==============================] - 0s 16ms/step
# >350, d=0.623, g=0.837, a=65
# 1/1 [==============================] - 0s 16ms/step
# >351, d=0.638, g=0.988, a=56
# 1/1 [==============================] - 0s 5ms/step
# >352, d=0.656, g=1.011, a=65
# 1/1 [==============================] - 0s 20ms/step
# >353, d=0.619, g=1.065, a=59
# 1/1 [==============================] - 0s 16ms/step
# >354, d=0.611, g=0.688, a=65
# 1/1 [==============================] - 0s 16ms/step
# >355, d=0.685, g=0.721, a=53
# 1/1 [==============================] - 0s 6ms/step
# >356, d=0.664, g=0.933, a=62
# 1/1 [==============================] - 0s 16ms/step
# >357, d=0.707, g=0.976, a=56
# 1/1 [==============================] - 0s 16ms/step
# >358, d=0.741, g=0.840, a=53
# 1/1 [==============================] - 0s 16ms/step
# >359, d=0.667, g=1.146, a=68
# 1/1 [==============================] - 0s 16ms/step
# >360, d=0.655, g=1.231, a=46
# 1/1 [==============================] - 0s 16ms/step
# >361, d=0.572, g=0.904, a=71
# 1/1 [==============================] - 0s 16ms/step
# >362, d=0.586, g=0.756, a=71
# 1/1 [==============================] - 0s 4ms/step
# >363, d=0.614, g=0.764, a=59
# 1/1 [==============================] - 0s 16ms/step
# >364, d=0.665, g=1.260, a=56
# 1/1 [==============================] - 0s 24ms/step
# >365, d=0.741, g=1.104, a=53
# 1/1 [==============================] - 0s 16ms/step
# >366, d=0.550, g=1.121, a=78
# 1/1 [==============================] - 0s 16ms/step
# >367, d=0.609, g=1.088, a=71
# 1/1 [==============================] - 0s 16ms/step
# >368, d=0.581, g=0.531, a=68
# 1/1 [==============================] - 0s 16ms/step
# >369, d=0.700, g=1.063, a=53
# 1/1 [==============================] - 0s 2ms/step
# >370, d=0.618, g=1.033, a=68
# 1/1 [==============================] - 0s 16ms/step
# >371, d=0.618, g=0.822, a=71
# 1/1 [==============================] - 0s 16ms/step
# >372, d=0.656, g=0.902, a=50
# 1/1 [==============================] - 0s 16ms/step
# >373, d=0.642, g=0.823, a=56
# 1/1 [==============================] - 0s 16ms/step
# >374, d=0.578, g=0.974, a=62
# 1/1 [==============================] - 0s 16ms/step
# >375, d=0.677, g=0.831, a=56
# 1/1 [==============================] - 0s 16ms/step
# >376, d=0.615, g=0.852, a=68
# 1/1 [==============================] - 0s 9ms/step
# >377, d=0.566, g=1.041, a=75
# 1/1 [==============================] - 0s 18ms/step
# >378, d=0.611, g=0.909, a=56
# 1/1 [==============================] - 0s 16ms/step
# >379, d=0.569, g=0.912, a=75
# 1/1 [==============================] - 0s 16ms/step
# >380, d=0.603, g=0.973, a=75
# 1/1 [==============================] - 0s 20ms/step
# >381, d=0.614, g=1.137, a=65
# 1/1 [==============================] - 0s 21ms/step
# >382, d=0.611, g=0.930, a=75
# 1/1 [==============================] - 0s 11ms/step
# >383, d=0.534, g=0.785, a=81
# 1/1 [==============================] - 0s 16ms/step
# >384, d=0.576, g=0.985, a=65
# 1/1 [==============================] - 0s 31ms/step
# >385, d=0.666, g=1.139, a=68
# 1/1 [==============================] - 0s 31ms/step
# >386, d=0.594, g=0.950, a=68
# 1/1 [==============================] - 0s 31ms/step
# >387, d=0.572, g=0.738, a=68
# 1/1 [==============================] - 0s 16ms/step
# >388, d=0.613, g=1.164, a=62
# 1/1 [==============================] - 0s 16ms/step
# >389, d=0.596, g=1.150, a=62
# 1/1 [==============================] - 0s 21ms/step
# >390, d=0.577, g=0.677, a=71
# 1/1 [==============================] - 0s 16ms/step
# >391, d=0.641, g=1.180, a=65
# 1/1 [==============================] - 0s 17ms/step
# >392, d=0.660, g=0.855, a=53
# 1/1 [==============================] - 0s 15ms/step
# >393, d=0.509, g=0.842, a=81
# 1/1 [==============================] - 0s 17ms/step
# >394, d=0.641, g=1.259, a=59
# 1/1 [==============================] - 0s 16ms/step
# >395, d=0.602, g=1.103, a=59
# 1/1 [==============================] - 0s 16ms/step
# >396, d=0.584, g=0.614, a=65
# 1/1 [==============================] - 0s 16ms/step
# >397, d=0.675, g=1.148, a=59
# 1/1 [==============================] - 0s 7ms/step
# >398, d=0.603, g=1.066, a=62
# 1/1 [==============================] - 0s 21ms/step
# >399, d=0.571, g=0.929, a=68
# 1/1 [==============================] - 0s 16ms/step
# >400, d=0.621, g=1.169, a=68
# 1/1 [==============================] - 0s 16ms/step
# >401, d=0.586, g=1.064, a=71
# 1/1 [==============================] - 0s 16ms/step
# >402, d=0.581, g=1.294, a=65
# 1/1 [==============================] - 0s 25ms/step
# >403, d=0.686, g=0.708, a=68
# 1/1 [==============================] - 0s 8ms/step
# >404, d=0.696, g=0.997, a=59
# 1/1 [==============================] - 0s 16ms/step
# >405, d=0.539, g=0.973, a=75
# 1/1 [==============================] - 0s 16ms/step
# >406, d=0.634, g=0.918, a=71
# 1/1 [==============================] - 0s 16ms/step
# >407, d=0.616, g=0.773, a=59
# 1/1 [==============================] - 0s 16ms/step
# >408, d=0.508, g=1.302, a=78
# 1/1 [==============================] - 0s 16ms/step
# >409, d=0.654, g=0.894, a=59
# 1/1 [==============================] - 0s 16ms/step
# >410, d=0.611, g=0.713, a=65
# 1/1 [==============================] - 0s 6ms/step
# >411, d=0.530, g=0.900, a=71
# 1/1 [==============================] - 0s 16ms/step
# >412, d=0.599, g=1.011, a=71
# 1/1 [==============================] - 0s 16ms/step
# >413, d=0.525, g=0.797, a=78
# 1/1 [==============================] - 0s 16ms/step
# >414, d=0.488, g=0.945, a=81
# 1/1 [==============================] - 0s 16ms/step
# >415, d=0.640, g=0.951, a=53
# 1/1 [==============================] - 0s 16ms/step
# >416, d=0.696, g=0.833, a=59
# 1/1 [==============================] - 0s 16ms/step
# >417, d=0.731, g=1.220, a=56
# 1/1 [==============================] - 0s 16ms/step
# >418, d=0.573, g=1.200, a=78
# 1/1 [==============================] - 0s 7ms/step
# >419, d=0.630, g=0.955, a=71
# 1/1 [==============================] - 0s 16ms/step
# >420, d=0.650, g=0.731, a=68
# 1/1 [==============================] - 0s 16ms/step
# >421, d=0.591, g=0.915, a=71
# 1/1 [==============================] - 0s 25ms/step
# >422, d=0.670, g=0.897, a=65
# 1/1 [==============================] - 0s 16ms/step
# >423, d=0.570, g=0.721, a=65
# 1/1 [==============================] - 0s 10ms/step
# >424, d=0.554, g=0.897, a=78
# 1/1 [==============================] - 0s 16ms/step
# >425, d=0.551, g=1.279, a=78
# 1/1 [==============================] - 0s 16ms/step
# >426, d=0.679, g=1.025, a=56
# 1/1 [==============================] - 0s 16ms/step
# >427, d=0.611, g=0.761, a=65
# 1/1 [==============================] - 0s 16ms/step
# >428, d=0.537, g=1.008, a=78
# 1/1 [==============================] - 0s 16ms/step
# >429, d=0.569, g=0.819, a=71
# 1/1 [==============================] - 0s 32ms/step
# >430, d=0.659, g=1.024, a=59
# 1/1 [==============================] - 0s 16ms/step
# >431, d=0.587, g=1.092, a=68
# 1/1 [==============================] - 0s 30ms/step
# >432, d=0.632, g=0.907, a=56
# 1/1 [==============================] - 0s 16ms/step
# >433, d=0.495, g=0.815, a=90
# 1/1 [==============================] - 0s 28ms/step
# >434, d=0.730, g=1.068, a=56
# 1/1 [==============================] - 0s 16ms/step
# >435, d=0.695, g=1.113, a=65
# 1/1 [==============================] - 0s 16ms/step
# >436, d=0.501, g=0.956, a=81
# 1/1 [==============================] - 0s 16ms/step
# >437, d=0.630, g=0.933, a=62
# 1/1 [==============================] - 0s 7ms/step
# >438, d=0.605, g=1.264, a=62
# 1/1 [==============================] - 0s 14ms/step
# >439, d=0.715, g=0.832, a=56
# 1/1 [==============================] - 0s 17ms/step
# >440, d=0.661, g=0.771, a=68
# 1/1 [==============================] - 0s 16ms/step
# >441, d=0.682, g=0.938, a=59
# 1/1 [==============================] - 0s 16ms/step
# >442, d=0.562, g=1.113, a=78
# 1/1 [==============================] - 0s 16ms/step
# >443, d=0.606, g=0.924, a=71
# 1/1 [==============================] - 0s 16ms/step
# >444, d=0.527, g=0.902, a=71
# 1/1 [==============================] - 0s 16ms/step
# >445, d=0.538, g=1.001, a=78
# 1/1 [==============================] - 0s 16ms/step
# >446, d=0.691, g=0.867, a=50
# 1/1 [==============================] - 0s 16ms/step
# >447, d=0.594, g=0.971, a=59
# 1/1 [==============================] - 0s 16ms/step
# >448, d=0.639, g=1.178, a=71
# 1/1 [==============================] - 0s 16ms/step
# >449, d=0.657, g=0.915, a=53
# 1/1 [==============================] - 0s 19ms/step
# >450, d=0.687, g=0.871, a=62
# 1/1 [==============================] - 0s 16ms/step
# >451, d=0.561, g=0.929, a=78
# 1/1 [==============================] - 0s 16ms/step
# >452, d=0.634, g=0.747, a=59
# 1/1 [==============================] - 0s 16ms/step
# >453, d=0.566, g=0.661, a=75
# 1/1 [==============================] - 0s 6ms/step
# >454, d=0.592, g=1.093, a=62
# 1/1 [==============================] - 0s 14ms/step
# >455, d=0.667, g=0.935, a=53
# 1/1 [==============================] - 0s 16ms/step
# >456, d=0.598, g=0.871, a=62
# 1/1 [==============================] - 0s 16ms/step
# >457, d=0.699, g=0.924, a=62
# 1/1 [==============================] - 0s 16ms/step
# >458, d=0.559, g=1.104, a=78
# 1/1 [==============================] - 0s 16ms/step
# >459, d=0.713, g=0.782, a=59
# 1/1 [==============================] - 0s 16ms/step
# >460, d=0.575, g=0.825, a=71
# 1/1 [==============================] - 0s 16ms/step
# >461, d=0.743, g=1.015, a=56
# 1/1 [==============================] - 0s 16ms/step
# >462, d=0.592, g=1.025, a=68
# 1/1 [==============================] - 0s 16ms/step
# >463, d=0.572, g=0.805, a=75
# 1/1 [==============================] - 0s 29ms/step
# >464, d=0.584, g=0.930, a=71
# 1/1 [==============================] - 0s 16ms/step
# >465, d=0.663, g=0.796, a=62
# 1/1 [==============================] - 0s 16ms/step
# >466, d=0.642, g=0.893, a=65
# 1/1 [==============================] - 0s 16ms/step
# >467, d=0.606, g=1.136, a=68
# 1/1 [==============================] - 0s 16ms/step
# >468, d=0.588, g=0.877, a=68
# 1/1 [==============================] - 0s 16ms/step
# >469, d=0.619, g=0.798, a=62
# 1/1 [==============================] - 0s 25ms/step
# >470, d=0.631, g=0.774, a=65
# 1/1 [==============================] - 0s 17ms/step
# >471, d=0.623, g=1.216, a=68
# 1/1 [==============================] - 0s 16ms/step
# >472, d=0.645, g=0.814, a=62
# 1/1 [==============================] - 0s 16ms/step
# >473, d=0.614, g=0.880, a=62
# 1/1 [==============================] - 0s 16ms/step
# >474, d=0.633, g=1.016, a=65
# 1/1 [==============================] - 0s 16ms/step
# >475, d=0.575, g=1.040, a=68
# 1/1 [==============================] - 0s 16ms/step
# >476, d=0.600, g=0.802, a=68
# 1/1 [==============================] - 0s 16ms/step
# >477, d=0.674, g=0.896, a=59
# 1/1 [==============================] - 0s 16ms/step
# >478, d=0.581, g=0.964, a=71
# 1/1 [==============================] - 0s 16ms/step
# >479, d=0.595, g=0.889, a=68
# 1/1 [==============================] - 0s 16ms/step
# >480, d=0.520, g=0.774, a=81
# 1/1 [==============================] - 0s 16ms/step
# >481, d=0.698, g=0.898, a=62
# 1/1 [==============================] - 0s 16ms/step
# >482, d=0.660, g=0.814, a=65
# 1/1 [==============================] - 0s 23ms/step
# >483, d=0.653, g=0.739, a=59
# 1/1 [==============================] - 0s 16ms/step
# >484, d=0.640, g=1.051, a=65
# 1/1 [==============================] - 0s 16ms/step
# >485, d=0.604, g=1.002, a=75
# 1/1 [==============================] - 0s 16ms/step
# >486, d=0.619, g=0.800, a=71
# 4/4 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# >487, d=0.688, g=1.120, a=65
# 1/1 [==============================] - 0s 19ms/step
# >488, d=0.661, g=1.171, a=59
# 1/1 [==============================] - 0s 16ms/step
# >489, d=0.571, g=0.811, a=68
# 1/1 [==============================] - 0s 16ms/step
# >490, d=0.620, g=0.866, a=59
# 1/1 [==============================] - 0s 16ms/step
# >491, d=0.586, g=1.145, a=78
# 1/1 [==============================] - 0s 16ms/step
# >492, d=0.701, g=0.881, a=59
# 1/1 [==============================] - 0s 31ms/step
# >493, d=0.542, g=0.763, a=81
# 1/1 [==============================] - 0s 31ms/step
# >494, d=0.583, g=0.808, a=78
# 1/1 [==============================] - 0s 16ms/step
# >495, d=0.577, g=1.060, a=71
# 1/1 [==============================] - 0s 16ms/step
# >496, d=0.543, g=0.797, a=75
# 1/1 [==============================] - 0s 16ms/step
# >497, d=0.633, g=0.958, a=68
# 1/1 [==============================] - 0s 31ms/step
# >498, d=0.554, g=1.026, a=68
# 1/1 [==============================] - 0s 16ms/step
# >499, d=0.508, g=0.751, a=84
# 1/1 [==============================] - 0s 16ms/step
# >500, d=0.559, g=1.093, a=78
# 1/1 [==============================] - 0s 16ms/step
# >501, d=0.527, g=1.180, a=71
# 1/1 [==============================] - 0s 16ms/step
# >502, d=0.565, g=0.846, a=68
# 1/1 [==============================] - 0s 31ms/step
# >503, d=0.577, g=0.696, a=75
# 1/1 [==============================] - 0s 16ms/step
# >504, d=0.595, g=1.620, a=71
# 1/1 [==============================] - 0s 21ms/step
# >505, d=0.551, g=1.401, a=68
# 1/1 [==============================] - 0s 16ms/step
# >506, d=0.432, g=1.294, a=81
# 1/1 [==============================] - 0s 35ms/step
# >507, d=0.544, g=1.070, a=78
# 1/1 [==============================] - 0s 16ms/step
# >508, d=0.435, g=0.932, a=84
# 1/1 [==============================] - 0s 18ms/step
# >509, d=0.507, g=1.153, a=78
# 1/1 [==============================] - 0s 28ms/step
# >510, d=0.466, g=1.685, a=84
# 1/1 [==============================] - 0s 16ms/step
# >511, d=0.468, g=1.344, a=71
# 1/1 [==============================] - 0s 33ms/step
# >512, d=0.505, g=1.060, a=65
# 1/1 [==============================] - 0s 16ms/step
# >513, d=0.394, g=1.027, a=81
# 1/1 [==============================] - 0s 16ms/step
# >514, d=0.409, g=1.038, a=87
# 1/1 [==============================] - 0s 18ms/step
# >515, d=0.512, g=1.463, a=84
# 1/1 [==============================] - 0s 17ms/step
# ...
# >1427, d=0.536, g=1.211, a=71
# 1/1 [==============================] - 0s 23ms/step
# >1428, d=0.597, g=0.746, a=68
# 1/1 [==============================] - 0s 20ms/step
# >1429, d=0.637, g=1.059, a=62
# 1/1 [==============================] - 0s 31ms/step
# >1430, d=0.534, g=1.111, a=71
# 1/1 [==============================] - 0s 28ms/step
# >1431, d=0.537, g=0.911, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1432, d=0.602, g=0.931, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1433, d=0.636, g=0.965, a=65
# 1/1 [==============================] - 0s 27ms/step
# >1434, d=0.571, g=1.146, a=75
# 1/1 [==============================] - 0s 21ms/step
# >1435, d=0.624, g=0.790, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1436, d=0.611, g=0.813, a=62
# 1/1 [==============================] - 0s 16ms/step
# >1437, d=0.604, g=1.071, a=59
# 1/1 [==============================] - 0s 16ms/step
# >1438, d=0.656, g=1.301, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1439, d=0.511, g=0.925, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1440, d=0.566, g=0.972, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1441, d=0.510, g=1.228, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1442, d=0.605, g=0.724, a=59
# 1/1 [==============================] - 0s 16ms/step
# >1443, d=0.642, g=1.087, a=59
# 1/1 [==============================] - 0s 31ms/step
# >1444, d=0.622, g=1.032, a=62
# 1/1 [==============================] - 0s 16ms/step
# >1445, d=0.601, g=1.080, a=59
# 1/1 [==============================] - 0s 16ms/step
# >1446, d=0.580, g=1.063, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1447, d=0.556, g=0.810, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1448, d=0.517, g=0.994, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1449, d=0.533, g=1.022, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1450, d=0.602, g=1.035, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1451, d=0.594, g=0.835, a=59
# 1/1 [==============================] - 0s 16ms/step
# >1452, d=0.481, g=1.163, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1453, d=0.413, g=1.363, a=84
# 1/1 [==============================] - 0s 16ms/step
# >1454, d=0.485, g=1.139, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1455, d=0.461, g=0.987, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1456, d=0.440, g=1.868, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1457, d=0.628, g=1.181, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1458, d=0.514, g=1.551, a=71
# 4/4 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1459, d=0.634, g=0.753, a=65
# 1/1 [==============================] - 0s 15ms/step
# >1460, d=0.568, g=1.514, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1461, d=0.594, g=1.270, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1462, d=0.621, g=0.502, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1463, d=0.898, g=1.852, a=53
# 1/1 [==============================] - 0s 16ms/step
# >1464, d=0.763, g=1.572, a=53
# 1/1 [==============================] - 0s 16ms/step
# >1465, d=0.508, g=0.938, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1466, d=0.589, g=0.747, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1467, d=0.587, g=0.644, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1468, d=0.588, g=0.894, a=62
# 1/1 [==============================] - 0s 16ms/step
# >1469, d=0.567, g=0.950, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1470, d=0.549, g=1.152, a=71
# 1/1 [==============================] - 0s 21ms/step
# >1471, d=0.535, g=1.002, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1472, d=0.527, g=0.958, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1473, d=0.530, g=0.869, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1474, d=0.643, g=1.367, a=56
# 1/1 [==============================] - 0s 16ms/step
# >1475, d=0.508, g=0.945, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1476, d=0.625, g=0.963, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1477, d=0.508, g=1.082, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1478, d=0.620, g=1.373, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1479, d=0.618, g=1.127, a=62
# 1/1 [==============================] - 0s 16ms/step
# >1480, d=0.594, g=0.779, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1481, d=0.534, g=1.273, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1482, d=0.576, g=1.438, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1483, d=0.621, g=1.118, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1484, d=0.417, g=1.295, a=84
# 1/1 [==============================] - 0s 16ms/step
# >1485, d=0.667, g=0.888, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1486, d=0.633, g=1.396, a=59
# 1/1 [==============================] - 0s 16ms/step
# >1487, d=0.576, g=1.218, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1488, d=0.449, g=0.759, a=87
# 1/1 [==============================] - 0s 31ms/step
# >1489, d=0.514, g=0.980, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1490, d=0.548, g=1.354, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1491, d=0.510, g=0.863, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1492, d=0.582, g=0.759, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1493, d=0.714, g=1.697, a=53
# 1/1 [==============================] - 0s 21ms/step
# >1494, d=0.642, g=1.171, a=62
# 1/1 [==============================] - 0s 8ms/step
# >1495, d=0.556, g=0.888, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1496, d=0.463, g=1.134, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1497, d=0.478, g=1.579, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1498, d=0.509, g=0.945, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1499, d=0.529, g=1.137, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1500, d=0.576, g=1.242, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1501, d=0.698, g=1.032, a=65
# 1/1 [==============================] - 0s 28ms/step
# >1502, d=0.547, g=0.664, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1503, d=0.672, g=1.125, a=62
# 1/1 [==============================] - 0s 28ms/step
# >1504, d=0.695, g=1.214, a=62
# 1/1 [==============================] - 0s 16ms/step
# >1505, d=0.663, g=0.813, a=56
# 1/1 [==============================] - 0s 16ms/step
# >1506, d=0.610, g=1.071, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1507, d=0.585, g=1.024, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1508, d=0.641, g=1.075, a=59
# 1/1 [==============================] - 0s 16ms/step
# >1509, d=0.604, g=0.598, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1510, d=0.779, g=1.012, a=46
# 1/1 [==============================] - 0s 16ms/step
# >1511, d=0.646, g=1.022, a=68
# 1/1 [==============================] - 0s 28ms/step
# >1512, d=0.769, g=0.792, a=46
# 1/1 [==============================] - 0s 23ms/step
# >1513, d=0.606, g=0.773, a=62
# 1/1 [==============================] - 0s 16ms/step
# >1514, d=0.710, g=1.019, a=56
# 1/1 [==============================] - 0s 16ms/step
# >1515, d=0.615, g=0.919, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1516, d=0.730, g=0.833, a=56
# 1/1 [==============================] - 0s 16ms/step
# >1517, d=0.675, g=0.776, a=53
# 1/1 [==============================] - 0s 16ms/step
# >1518, d=0.711, g=0.832, a=56
# 1/1 [==============================] - 0s 16ms/step
# >1519, d=0.671, g=0.972, a=56
# 1/1 [==============================] - 0s 16ms/step
# >1520, d=0.592, g=0.948, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1521, d=0.732, g=0.853, a=50
# 1/1 [==============================] - 0s 16ms/step
# >1522, d=0.595, g=0.881, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1523, d=0.732, g=0.893, a=46
# 1/1 [==============================] - 0s 16ms/step
# >1524, d=0.721, g=0.948, a=53
# 1/1 [==============================] - 0s 16ms/step
# >1525, d=0.610, g=0.915, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1526, d=0.572, g=0.946, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1527, d=0.647, g=0.896, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1528, d=0.608, g=0.939, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1529, d=0.479, g=0.854, a=84
# 1/1 [==============================] - 0s 31ms/step
# >1530, d=0.479, g=0.966, a=87
# 1/1 [==============================] - 0s 28ms/step
# >1531, d=0.489, g=0.917, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1532, d=0.514, g=1.032, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1533, d=0.437, g=1.099, a=84
# 1/1 [==============================] - 0s 16ms/step
# >1534, d=0.371, g=1.002, a=93
# 1/1 [==============================] - 0s 16ms/step
# >1535, d=0.452, g=1.210, a=84
# 1/1 [==============================] - 0s 9ms/step
# >1536, d=0.606, g=1.583, a=68
# 1/1 [==============================] - 0s 31ms/step
# >1537, d=0.488, g=1.220, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1538, d=0.462, g=0.968, a=87
# 1/1 [==============================] - 0s 27ms/step
# >1539, d=0.568, g=1.331, a=65
# 1/1 [==============================] - 0s 18ms/step
# >1540, d=0.439, g=1.502, a=84
# 1/1 [==============================] - 0s 31ms/step
# >1541, d=0.354, g=1.426, a=90
# 1/1 [==============================] - 0s 16ms/step
# >1542, d=0.431, g=0.723, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1543, d=0.560, g=1.860, a=71
# 1/1 [==============================] - 0s 28ms/step
# >1544, d=0.519, g=1.470, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1545, d=0.457, g=1.460, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1546, d=0.583, g=1.122, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1547, d=0.504, g=1.469, a=78
# 1/1 [==============================] - 0s 31ms/step
# >1548, d=0.427, g=1.330, a=87
# 1/1 [==============================] - 0s 31ms/step
# >1549, d=0.485, g=1.113, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1550, d=0.473, g=1.196, a=87
# 1/1 [==============================] - 0s 16ms/step
# >1551, d=0.512, g=1.653, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1552, d=0.813, g=0.634, a=59
# 1/1 [==============================] - 0s 16ms/step
# >1553, d=0.780, g=1.432, a=59
# 1/1 [==============================] - 0s 16ms/step
# >1554, d=0.734, g=1.067, a=53
# 1/1 [==============================] - 0s 16ms/step
# >1555, d=0.586, g=0.609, a=62
# 1/1 [==============================] - 0s 16ms/step
# >1556, d=1.097, g=1.622, a=46
# 1/1 [==============================] - 0s 16ms/step
# >1557, d=0.702, g=0.977, a=53
# 1/1 [==============================] - 0s 16ms/step
# >1558, d=0.723, g=1.037, a=46
# 1/1 [==============================] - 0s 16ms/step
# >1559, d=0.672, g=0.890, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1560, d=0.627, g=0.983, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1561, d=0.687, g=1.017, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1562, d=0.564, g=1.428, a=62
# 1/1 [==============================] - 0s 16ms/step
# >1563, d=0.640, g=1.337, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1564, d=0.453, g=1.162, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1565, d=0.524, g=1.465, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1566, d=0.419, g=1.297, a=84
# 1/1 [==============================] - 0s 16ms/step
# >1567, d=0.447, g=1.168, a=81
# 1/1 [==============================] - 0s 31ms/step
# >1568, d=0.512, g=1.373, a=71
# 1/1 [==============================] - 0s 31ms/step
# >1569, d=0.431, g=1.347, a=84
# 1/1 [==============================] - 0s 28ms/step
# >1570, d=0.483, g=1.207, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1571, d=0.487, g=1.442, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1572, d=0.579, g=1.609, a=65
# 1/1 [==============================] - 0s 31ms/step
# >1573, d=0.455, g=1.028, a=78
# 1/1 [==============================] - 0s 21ms/step
# >1574, d=0.504, g=1.840, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1575, d=0.639, g=1.264, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1576, d=0.499, g=0.783, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1577, d=0.589, g=1.467, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1578, d=0.450, g=1.406, a=87
# 1/1 [==============================] - 0s 16ms/step
# >1579, d=0.542, g=0.972, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1580, d=0.563, g=0.939, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1581, d=0.697, g=1.523, a=59
# 1/1 [==============================] - 0s 16ms/step
# >1582, d=0.457, g=1.443, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1583, d=0.596, g=0.865, a=62
# 1/1 [==============================] - 0s 16ms/step
# >1584, d=0.563, g=0.878, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1585, d=0.555, g=1.021, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1586, d=0.568, g=1.029, a=75
# 1/1 [==============================] - 0s 32ms/step
# >1587, d=0.550, g=1.093, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1588, d=0.410, g=1.091, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1589, d=0.592, g=1.258, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1590, d=0.552, g=1.164, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1591, d=0.611, g=1.187, a=56
# 1/1 [==============================] - 0s 31ms/step
# >1592, d=0.490, g=1.041, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1593, d=0.675, g=1.584, a=56
# 1/1 [==============================] - 0s 16ms/step
# >1594, d=0.618, g=1.186, a=62
# 1/1 [==============================] - 0s 31ms/step
# >1595, d=0.556, g=1.021, a=62
# 1/1 [==============================] - 0s 15ms/step
# >1596, d=0.441, g=0.922, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1597, d=0.523, g=1.029, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1598, d=0.652, g=1.439, a=50
# 1/1 [==============================] - 0s 16ms/step
# >1599, d=0.533, g=0.943, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1600, d=0.446, g=0.683, a=84
# 1/1 [==============================] - 0s 31ms/step
# >1601, d=0.637, g=1.458, a=65
# 1/1 [==============================] - 0s 16ms/step
# >1602, d=0.480, g=1.251, a=78
# 1/1 [==============================] - 0s 16ms/step
# >1603, d=0.525, g=0.891, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1604, d=0.649, g=1.356, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1605, d=0.557, g=0.895, a=62
# 1/1 [==============================] - 0s 16ms/step
# >1606, d=0.541, g=1.233, a=68
# 1/1 [==============================] - 0s 16ms/step
# >1607, d=0.511, g=1.507, a=68
# 1/1 [==============================] - 0s 28ms/step
# >1608, d=0.450, g=1.503, a=81
# 1/1 [==============================] - 0s 16ms/step
# >1609, d=0.412, g=1.209, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1610, d=0.458, g=1.385, a=75
# 1/1 [==============================] - 0s 20ms/step
# >1611, d=0.519, g=1.082, a=71
# 1/1 [==============================] - 0s 15ms/step
# >1612, d=0.518, g=1.508, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1613, d=0.377, g=1.622, a=84
# 1/1 [==============================] - 0s 16ms/step
# >1614, d=0.488, g=1.194, a=75
# 1/1 [==============================] - 0s 21ms/step
# >1615, d=0.447, g=0.917, a=78
# 1/1 [==============================] - 0s 31ms/step
# >1616, d=0.499, g=1.484, a=71
# 1/1 [==============================] - 0s 28ms/step
# >1617, d=0.519, g=1.320, a=71
# 1/1 [==============================] - 0s 16ms/step
# >1618, d=0.531, g=1.563, a=78
# 1/1 [==============================] - 0s 31ms/step
# >1619, d=0.565, g=1.100, a=75
# 1/1 [==============================] - 0s 16ms/step
# >1620, d=0.539, g=1.034, a=75
# 4/4 [==============================] - 0s 26ms/step

# %%
plt.imshow(dataset[0,:,:,0])

# %% [markdown]
# # Generacion de Modelos

# %%
# create and save a plot of generated images (reversed grayscale)
def save_plot_predict(examples, n):
  # plot images
  for i in range(n * n):
    # define subplot
    plt.subplot(n, n, 1 + i)
    # turn off axis
    plt.axis('off')
    # plot raw pixel data
    plt.imshow(examples[i, :, :, 0], cmap='gray_r')
  plt.show()

# %%
# load model
model = load_model('generator_2D_model_100.h5')
# generate images
latent_points = generate_latent_points(100, 25)
# generate images
X = model.predict(latent_points)
# plot the result
save_plot_predict(X, 5)
