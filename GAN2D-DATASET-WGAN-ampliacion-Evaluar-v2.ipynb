# %%
import torch
import tensorflow
from tensorflow.python.client import device_lib
def print_info():
    print('  Versión de TensorFlow: {}'.format(tensorflow.__version__))
    print('  GPU: {}'.format([x.physical_device_desc for x in device_lib.list_local_devices() if x.device_type == 'GPU']))
    print('  Versión Cuda  -> {}'.format(tensorflow.sysconfig.get_build_info()['cuda_version']))
    print('  Versión Cudnn -> {}\n'.format(tensorflow.sysconfig.get_build_info()['cudnn_version']))

print_info()
# Out:
#   Versión de TensorFlow: 2.9.0
#   GPU: ['device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5']
#   Versión Cuda  -> 64_112
#   Versión Cudnn -> 64_8

# %%
#Import from library
from datetime import date, time, datetime
import numpy as np
import cv2
import os
import pandas as pd
#mediciones librerias
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from skimage.measure import label, regionprops, regionprops_table
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KernelDensity
from sklearn.metrics import pairwise_distances
from skimage.metrics import structural_similarity as ssim
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing import image
from scipy.linalg import sqrtm
from scipy.stats import entropy
from scipy.stats import norm
#acomodar imagenes
from os import makedirs
#Importar libreriasfrom numpy import expand_dims
from numpy import mean
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import vstack
from keras import backend
from numpy.random import randn
from numpy.random import randint
from keras.models import Sequential
from keras.optimizers import Adam
from keras.optimizers import RMSprop
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import Dropout
from keras.layers import LeakyReLU
from keras.layers import BatchNormalization
from keras.initializers import RandomNormal
from keras.constraints import Constraint
#from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
# example of loading the mnist dataset
from keras.datasets.mnist import load_data
# load saved models
from keras.models import load_model

# %%
# Directorio que contiene tus imágenes
data_dir = 'Imagenes\data_all'

# Obtén la lista de nombres de archivo de las imágenes
image_filenames = sorted(os.listdir(data_dir))

# Crea un DataFrame de pandas con las rutas de las imágenes
df = pd.DataFrame({'filename': image_filenames})

# Configurar el generador de imágenes
image_size = (224, 224)
batch_size = 32
# Función para escalar de [0, 255] a [-1, 1]
def scale_to_minus_one_one(x):
    return (x / 127.5) - 1.0

# Configurar el generador de datos de imágenes
data_generator = ImageDataGenerator(
    preprocessing_function=scale_to_minus_one_one  # Aplicar la función de escala
)


# Crear un generador de lotes para el conjunto de datos de entrenamiento
train_generator = data_generator.flow_from_dataframe(
    df,
    directory=data_dir,
    x_col='filename',
    y_col=None,
    target_size=image_size,
    batch_size=16,
    class_mode=None,  # No hay clases específicas
    shuffle=True,
    seed=42,  # Para reproducibilidad
    color_mode = 'grayscale',
)


# Obtener el número total de muestras en el conjunto de datos
total_samples = len(train_generator.filenames)

# Obtener el número total de pasos por época
steps_per_epoch = total_samples // batch_size

# Imprimir información sobre el conjunto de datos
print("Total de muestras:", total_samples)
print("Pasos por época:", steps_per_epoch)
# Out:
# Found 5200 validated image filenames.
# Total de muestras: 5200
# Pasos por época: 162

# %%
## Creacion de Dataset
data_img=[]
for num in range(1,5201):
    num_img = str(num).rjust(5,'0')
    dir_img = 'Imagenes\data_all\{}.png'.format(num_img)
    temp_img= cv2.imread(dir_img, cv2.IMREAD_GRAYSCALE)
    #th, im_th = cv2.threshold(temp_img, 128, 255, cv2.THRESH_BINARY)
    #plt.imshow(temp_img)
    resize = cv2.resize(temp_img,(56,56),interpolation = cv2.INTER_CUBIC)
    data_img.append(resize)
data_img = np.asarray(data_img)
#data_img = data_img / 255.0
#normalizamos
data_img=(data_img-127.5) / 127.5
data_img = data_img.reshape(5200,56,56,1)

# %%
# plot images from the training dataset
for i in range(25):
    # define subplot
    plt.subplot(5, 5, 1 + i)
    # turn off axis
    plt.axis('off')
    # plot raw pixel data
    plt.imshow(data_img[i], cmap='gray_r')
#filename = 'base_plot_2DGAN{}.png'.format(str(date.today()))
#plt.savefig(filename)
#plt.close()
#summarize the shape of the dataset
print(data_img.shape)
# Out:
# (5200, 56, 56, 1)

# %%
# clip model weights to a given hypercube
class ClipConstraint(Constraint):
# set clip value when initialized
    def __init__(self, clip_value):
        self.clip_value = clip_value
# clip model weights to hypercube
    def __call__(self, weights):
        return backend.clip(weights, -self.clip_value, self.clip_value)
# get the config
    def get_config(self):
        return {'clip_value': self.clip_value}

# %%
# calculate wasserstein loss
def wasserstein_loss(y_true, y_pred):
    return backend.mean(y_true * y_pred)

# %%
# define the standalone critic model
def define_critic(in_shape=(224,224,1)):
    # weight initialization
    init = RandomNormal(stddev=0.2)
    # weight constraint
    const = ClipConstraint(0.01)
    # define model
    model = Sequential()
    #downsample to 14x14
    model.add(Conv2D(32,
                     (3,3),
                     strides=(2,2),
                     padding='same',
                     #kernel_initializer = init,
                     kernel_constraint = const,
                     input_shape=in_shape))
    #model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    #downsample to 7x7
    model.add(Conv2D(64,
                     (3,3),
                     strides=(2,2),
                     padding='same',
                     #kernel_initializer = init,
                     kernel_constraint = const))
    #model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    #downsample to 7x7
    model.add(Conv2D(64,
                     (3,3),
                     strides=(2,2),
                     padding='same',
                     #kernel_initializer = init,
                     kernel_constraint = const))
    #model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    
    model.add(Conv2D(128,
                     (3,3),
                     strides=(2,2),
                     padding='same',
                     #kernel_initializer = init,
                     kernel_constraint = const))
    #model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    model.add(Conv2D(128,
                     (3,3),
                     strides=(2,2),
                     padding='same',
                     #kernel_initializer = init,
                     kernel_constraint = const))
    #model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    #scoring,linear activation
    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    
    model.add(Dense(1, activation='linear'))
    
    model.summary()
    #compile model
    opt = RMSprop(learning_rate=0.0005)
    model.compile(optimizer=opt,
                  loss=wasserstein_loss)
    return model

# %%
#define the standalone generator model
def define_generator(latent_dim):
    # weight initialization
    init = RandomNormal(stddev=0.02)
    #define model
    model = Sequential()
    #foundation for 7x7 image
    n_nodes =256 *7*7 #features maps*dimensions
    model.add(Dense(n_nodes,
                    #kernel_initializer = init,
                    input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Reshape((7, 7, 256)))
    # upsample to 14x14
    model.add(Conv2DTranspose(128,
                              (3,3),
                              strides=(2,2),
                              #kernel_initializer = init,
                              padding='same'
                             ))
    #model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 28x28
    model.add(Conv2DTranspose(128,
                              (3,3),
                              strides=(2,2),
                              #kernel_initializer = init,
                              padding='same'))
    #model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 56x56
    model.add(Conv2DTranspose(64,
                              (3,3),
                              strides=(2,2),
                              #kernel_initializer = init,
                              padding='same'))
    #model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 56x56
    model.add(Conv2DTranspose(32,
                              (3,3),
                              strides=(2,2),
                              #kernel_initializer = init,
                              padding='same'))
    #model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 56x56
    model.add(Conv2DTranspose(16,
                              (3,3),
                              strides=(2,2),
                              #kernel_initializer = init,
                              padding='same'))
    #model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    #output 28x28x1
    model.add(Conv2D(1,
                     (7,7),
                     activation='tanh',
                     #kernel_initializer = init,
                     padding='same'))
    model.summary()
    return model

# %%
#define the combined generator and dicriminatro model,
#for updating the generator
def define_gan(generator,critic):
    #make weights in the discriminator not trainable
    critic.trainable = False
    #connect them
    model = Sequential()
    # add generator
    model.add(g_model)
    #add the discriminator
    model.add(critic)
    model.summary()
    #compile model
    opt = RMSprop(learning_rate=0.00005)
    model.compile(optimizer=opt,
                  loss=wasserstein_loss)
    return model

# %%
## load and prepare mnist training images
def load_real_samples():
    # load mnist dataset
    #(trainX, _), (_, _) = data_img
    (trainX, trainy), (_, _) = load_data()
    # select all of the examples for a given class
    selected_ix = trainy == 7
    X = trainX[selected_ix]
    # expand to 3d, e.g. add channels dimension
    #X = expand_dims(trainX, axis=-1)
    X = expand_dims(X, axis=-1)
    # convert from unsigned ints to floats
    X = X.astype('float32')
    # scale from [0,255] to [-1 ,1]
    #X = X / 255.0 #[0 ,1]
    X = (X-127.5) / 127.5
    return X

# %%
# select real samples
def generate_real_samples(dataset, n_samples):
    # choose random instances
    ix = randint(0, dataset.shape[0], n_samples)
    # retrieve selected images
    X = dataset[ix]
    # generate class labels, -1 for ✬real✬
    y = -ones((n_samples, 1))
    return X, y

# %%
def generate_real_samples_v2(n_samples):
    
    # Obtener un lote de muestras reales del generador de imágenes
    batch = train_generator.next()
    #print(batch.shape)
    #X = batch[0]  # La primera parte del lote son las imágenes
    #print(X.shape)
    #print(batch[1].shape)
    # generate ✬real✬ class labels (1)
    y = -ones((n_samples, 1))
    
    return batch, y

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
    # generate points in the latent space
    x_input = randn(latent_dim * n_samples)
    # reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, latent_dim)
    return x_input

# %%
# use the generator to generate n fake examples, with class labels
def generate_fake_samples(g_model, latent_dim, n_samples):
    # generate points in latent space
    x_input = generate_latent_points(latent_dim, n_samples)
    # predict outputs
    X = g_model.predict(x_input)
    # create class labels with 1.0 for ✬fake
    y = ones((n_samples, 1))
    return X, y

# %%
# create and save a plot of generated images (reversed grayscale)
def save_plot(examples, epoch, n=10):
    # plot images
    for i in range(n * n):
        # define subplot
        plt.subplot(n,n, 1+i)
        # turn off axis
        plt.axis('off')
        # plot raw pixel data
        plt.imshow(examples[i, :, :, 0],
                   cmap='gray_r')
    # save plot to file
    filename = 'results/WGANRe3/generated_2WGAN_plot_e%04d.png' % (epoch+1)
    plt.savefig(filename)
    plt.close()

# %%
def calculate_ssim(images_real, images_generated):
    ssim_scores = []

    for i in range(len(images_real)):
        
        # Desempaqueta las imágenes de un solo canal si es necesario
        img_real = np.squeeze(images_real[i])
        img_generated = np.squeeze(images_generated[i])

        # Calcula el SSIM entre las dos imágenes
        score, _ = ssim(img_real, img_generated, data_range=img_real.max() - img_real.min(), full=True)
        ssim_scores.append(score)

    average_ssim = np.mean(ssim_scores)
    
    return average_ssim

# %%
def compute_mmd(real_images, generated_images):
    # Aplanar las imágenes
    real_images_flat = real_images.reshape((len(real_images), -1))
    generated_images_flat = generated_images.reshape((len(generated_images), -1))

    # Calcular las matrices de distancia
    real_distances = pairwise_distances(real_images_flat, real_images_flat)
    generated_distances = pairwise_distances(generated_images_flat, generated_images_flat)
    cross_distances = pairwise_distances(real_images_flat, generated_images_flat)

    # Calcular las estimaciones del kernel
    real_kernel = np.mean(np.exp(-0.5 * real_distances**2))
    generated_kernel = np.mean(np.exp(-0.5 * generated_distances**2))
    cross_kernel = np.mean(np.exp(-0.5 * cross_distances**2))

    # Calcular la MMD
    mmd = real_kernel + generated_kernel - 2 * cross_kernel

    return mmd

# %%
def calculate_kde(images_set):
    # Aplanar y normalizar las imágenes
    flattened_images = images_set.reshape((len(images_set), -1))

    # Definir la Estimación de Densidad de Kernel (KDE)
    kde = KernelDensity(bandwidth=0.5)
    kde.fit(flattened_images)

    # Generar nuevos datos para evaluar la densidad de KDE
    num_samples = 1000
    samples = np.random.normal(0, 1, size=(num_samples, flattened_images.shape[1]))

    # Calcular la densidad de KDE en los nuevos datos
    log_density = kde.score_samples(samples)

    # Calcular la entropía de KDE
    entropy_value = -np.mean(log_density)

    return entropy_value

# %%
def coverage_metric(real_images, generated_images, k=5):
    # Aplanar las imágenes
    real_images_flat = real_images.reshape((len(real_images), -1))
    generated_images_flat = generated_images.reshape((len(generated_images), -1))

    # Entrenar un modelo de vecinos más cercanos en datos reales
    neighbors_real = NearestNeighbors(n_neighbors=k)
    neighbors_real.fit(real_images_flat)

    # Encontrar los k vecinos más cercanos de cada muestra generada en datos reales
    distances, _ = neighbors_real.kneighbors(generated_images_flat)

    # Calcular la métrica de cobertura como la fracción de muestras generadas que tienen vecinos en datos reales
    coverage = np.mean(np.min(distances, axis=1) <= 0.0)

    return coverage

# %%
# evaluate the discriminator, plot generated images, save generator model
def summarize_performance(epoch, g_model,dataset, latent_dim, n_samples=100):
    # prepare fake examples
    X, _ = generate_fake_samples(g_model, latent_dim, n_samples)
    # scale from [-1,1] to [0,1]
    x_fake = (X + 1) / 2.0
    # evaluate the discriminator, plot generated images, save generator model
    Xr, _ = generate_real_samples_v2( n_samples)
    Xr = (Xr + 1) / 2.0
    x_real = Xr*-1
    #evaluate model
    #print(x_fake.shape)
    ssim_score = calculate_ssim(Xr,x_fake)
    
    mmd_score = calculate_ssim(Xr,x_fake)
    
    coverage = coverage_metric(Xr,x_fake)
    
    fake_kde = calculate_kde(x_fake)
    real_kde = calculate_kde(Xr)
    
    save_plot(x_fake, epoch)
    # save the generator model tile file
    #filename = 'results/WGANRi/models/generator_2D_model_%03d.h5' % (epoch + 1)
    #g_model.save(filename)
    return ssim_score,fake_kde,real_kde,mmd_score,coverage#,fid_score

# %%
# create a line plot of loss for the gan and save to file
def plot_history(d1_hist, d2_hist, g_hist):
    # plot history
    plt.plot(d1_hist, label='crit_real')
    plt.plot(d2_hist, label='crit_fake')
    plt.plot(g_hist, label='gen')
    plt.legend()
    plt.savefig('results/WGANRe3/eval/plot_line_plot_loss.png')
    plt.close()

# %%
def plot_ssim(ssim):#,fid):
    
    plt.plot(ssim, label = 'ssim score')
    plt.legend()
    
    # save plot to file
    plt.savefig('results/WGANRe3/eval/plot_evaluation_ssim.png')
    plt.close()

# %%
def plot_coverage(coverage):#,fid):
    
    plt.plot(coverage, label = 'coverage')
    plt.legend()
    
    # save plot to file
    plt.savefig('results/WGANRe3/eval/plot_evaluation_coverage.png')
    plt.close()

# %%
def plot_mmd(mmd):#,fid):
    
    plt.plot(mmd, label = 'mmd score')
    plt.legend()
    
    # save plot to file
    plt.savefig('results/WGANRe3/eval/plot_evaluation_mmd.png')
    plt.close()

# %%
def plot_kde(rKde, fKde):#,fid):
    
    plt.plot(rKde, label = 'real KDE')
    plt.plot(fKde, label = 'fake KDE')
    plt.legend()
    
    # save plot to file
    plt.savefig('results/WGANRe3/eval/plot_evaluation_KDE.png')
    plt.close()

# %%
# train the generator and discriminator
def train(g_model, c_model, gan_model, dataset, latent_dim,
          n_epochs=20, n_batch=batch_size,n_critic=5):
    # calculate the number of batches per training epoch
    bat_per_epo = int(dataset.shape[0] / n_batch)
    # calculate the number of training iterations
    n_steps = bat_per_epo * n_epochs
    # calculate the size of half a batch of samples
    half_batch = int(n_batch / 2)
    
    # lists for keeping track of loss
    c1_hist, c2_hist, g_hist = list(), list(), list()
    
    #prepare lists for storing evaluation each iteration
    ssim,fkde,rkde,mmd,coverage = list(),list(),list(),list(),list()
    
    # manually enumerate epochs
    for i in range(n_steps):
        # update the critic more than the generator
        c1_tmp, c2_tmp = list(), list()
        # enumerate batches over the training set
        for _ in range(n_critic):
            # get randomly selected ✬real✬ samples
            X_real, y_real = generate_real_samples_v2(half_batch)
            # generate ✬fake✬ examples
            X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
           # update critic model weights
            c_loss1 = c_model.train_on_batch(X_real, y_real)
            #print(c_loss1)
            c1_tmp.append(c_loss1)
            # update critic model weights
            c_loss2 = c_model.train_on_batch(X_fake, y_fake)
            #print(c_loss2)
            c2_tmp.append(c_loss2)
        # store critic loss
        c1_hist.append(mean(c1_tmp))
        c2_hist.append(mean(c2_tmp))
        # prepare points in latent space as input for the generator
        X_gan = generate_latent_points(latent_dim, n_batch)
        # create inverted labels for the fake samples
        y_gan = -ones((n_batch, 1))
        # update the generator via the critic✬s error
        g_loss = gan_model.train_on_batch(X_gan, y_gan)
        #print(g_loss)
        g_hist.append(g_loss)
        # evaluate the model performance every ✬epoch✬
        print('>%d, c1=%.3f, c2=%.3f, g=%.3f' % (i+1,  c1_hist[-1], c2_hist[-1], g_loss))
    
        # evaluate the model performance, sometimes
        if (i+1) % bat_per_epo == 0:
            ssimScore,fKDE,rKDE,mmdScore,cScore = summarize_performance(i, g_model, dataset, latent_dim)
            #epoch, g_model, d_model, dataset, latent_dim,
            ssim.append(ssimScore)
            fkde.append(fKDE)
            rkde.append(rKDE)
            mmd.append(mmdScore)
            coverage.append(cScore)
            
    #line plots of loss
    plot_history(c1_hist, c2_hist, g_hist)
    plot_ssim(ssim)
    plot_kde(rkde,fkde)
    plot_mmd(mmd)
    plot_coverage(coverage)

# %%
#Make folder in dir
makedirs('results/WGANRe3', exist_ok=True)
makedirs('results/WGANRe3/eval', exist_ok=True)
# size of the latent space
latent_dim = 100
# create the discriminator
critic = define_critic()
# create the
g_model = define_generator(latent_dim)
# create the gan
gan_model = define_gan(g_model, critic)
# load image data
dataset = data_img
#dataset = load_real_samples()

# train model
train(g_model, critic, gan_model, dataset, latent_dim,n_epochs=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 112, 112, 32)      320
#
#  leaky_re_lu (LeakyReLU)     (None, 112, 112, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 56, 56, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        36928
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 28, 28, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 128)       73856
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 14, 14, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 128)         147584
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 7, 7, 128)         0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 4096)              25694208
#
#  dense_1 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 25,975,489
# Trainable params: 25,975,489
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 12544)             1266944
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 12544)             0
#
#  reshape (Reshape)           (None, 7, 7, 256)         0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 128)      295040
#  nspose)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 14, 14, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 128)      147584
#  ranspose)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 28, 28, 128)       0
#
#  conv2d_transpose_2 (Conv2DT  (None, 56, 56, 64)       73792
#  ranspose)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 56, 56, 64)        0
#
#  conv2d_transpose_3 (Conv2DT  (None, 112, 112, 32)     18464
#  ranspose)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 112, 112, 32)      0
#
#  conv2d_transpose_4 (Conv2DT  (None, 224, 224, 16)     4624
#  ranspose)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 224, 224, 16)      0
#
#  conv2d_5 (Conv2D)           (None, 224, 224, 1)       785
#
# =================================================================
# Total params: 1,807,233
# Trainable params: 1,807,233
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 224, 224, 1)       1807233
#
#  sequential (Sequential)     (None, 1)                 25975489
#
# =================================================================
# Total params: 27,782,722
# Trainable params: 1,807,233
# Non-trainable params: 25,975,489
# _________________________________________________________________
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 21ms/step
# >1, c1=0.056, c2=0.021, g=0.011
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# >2, c1=0.003, c2=0.017, g=-0.007
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# >3, c1=-0.005, c2=0.012, g=-0.004
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >4, c1=-0.003, c2=0.007, g=-0.002
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >5, c1=-0.002, c2=0.008, g=-0.002
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >6, c1=-0.006, c2=0.029, g=0.019
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >7, c1=-5.815, c2=-1.359, g=20.133
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 877us/step
# >8, c1=-1331.785, c2=-291.819, g=1169.931
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >9, c1=-14245.379, c2=-2680.852, g=5166.381
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >10, c1=-33589.194, c2=-6931.754, g=10071.875
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >11, c1=-50729.875, c2=-12117.145, g=16026.327
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 0s/step
# >12, c1=-68234.210, c2=-18658.749, g=23771.303
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# >13, c1=-84656.541, c2=-26346.952, g=31960.541
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# >14, c1=-106776.936, c2=-35327.671, g=42085.922
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# >15, c1=-128813.109, c2=-46048.241, g=53963.465
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# >16, c1=-153915.122, c2=-57737.334, g=66444.641
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >17, c1=-183641.016, c2=-71338.039, g=81589.562
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# >18, c1=-214782.841, c2=-87061.511, g=98489.211
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# >19, c1=-246820.325, c2=-104411.603, g=116978.953
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >20, c1=-283859.625, c2=-122098.239, g=135357.594
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# >21, c1=-314089.888, c2=-141331.084, g=155762.156
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# >22, c1=-354417.463, c2=-161185.428, g=176691.484
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# >23, c1=-389480.700, c2=-180132.700, g=194340.984
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >24, c1=-426625.275, c2=-196969.722, g=210482.531
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >25, c1=-488462.194, c2=-213545.875, g=228511.719
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >26, c1=-531294.856, c2=-230672.169, g=246162.406
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >27, c1=-575008.050, c2=-249197.497, g=265486.812
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >28, c1=-642082.750, c2=-267583.037, g=285192.062
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 8ms/step
# >29, c1=-689733.875, c2=-289629.906, g=308768.031
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >30, c1=-744060.675, c2=-312028.237, g=330866.688
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# >31, c1=-794487.375, c2=-333897.675, g=353318.812
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >32, c1=-886254.863, c2=-355039.044, g=375510.406
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >33, c1=-923259.225, c2=-377976.987, g=399982.688
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# >34, c1=-978172.725, c2=-402627.625, g=423719.938
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >35, c1=-1072370.975, c2=-425034.944, g=447824.938
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >36, c1=-1158493.525, c2=-450401.069, g=476364.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >37, c1=-1233725.925, c2=-474421.800, g=503021.688
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# >38, c1=-1281693.275, c2=-497038.794, g=529132.625
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 0s/step
# >39, c1=-1384822.725, c2=-522251.231, g=556666.000
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 10ms/step
# >40, c1=-1453187.425, c2=-551595.912, g=588525.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >41, c1=-1509520.500, c2=-569776.950, g=611911.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# >42, c1=-1621193.350, c2=-590150.988, g=630932.625
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 1ms/step
# >43, c1=-1715904.375, c2=-610703.312, g=657566.500
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 10ms/step
# >44, c1=-1776683.125, c2=-633569.550, g=677447.875
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# >45, c1=-1887952.400, c2=-643363.938, g=695455.625
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >46, c1=-1984508.500, c2=-658013.425, g=702652.188
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 0s/step
# >47, c1=-2087592.075, c2=-674937.550, g=718771.562
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# >48, c1=-2184211.000, c2=-674201.488, g=729957.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >49, c1=-2219411.400, c2=-672196.325, g=726476.000
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >50, c1=-2350000.700, c2=-660918.062, g=744590.500
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >51, c1=-2449777.450, c2=-672454.863, g=732673.438
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# >52, c1=-2528979.400, c2=-653766.300, g=729521.000
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# >53, c1=-2694255.700, c2=-652571.275, g=713961.875
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >54, c1=-2767831.550, c2=-621056.425, g=714732.625
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# >55, c1=-2878433.700, c2=-625326.037, g=726844.750
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# >56, c1=-2963657.950, c2=-589482.787, g=732013.938
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# >57, c1=-3083386.550, c2=-553539.338, g=727664.250
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >58, c1=-3149433.350, c2=-482283.675, g=705280.250
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# >59, c1=-3254815.100, c2=-462876.631, g=695446.875
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# >60, c1=-3371984.450, c2=-417059.213, g=609525.000
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >61, c1=-3488793.550, c2=-348917.006, g=539803.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# >62, c1=-3549083.050, c2=-196424.447, g=544978.375
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >63, c1=-3593264.700, c2=-143691.730, g=458352.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >64, c1=-3739417.550, c2=31521.594, g=392912.094
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >65, c1=-3724494.700, c2=147248.350, g=411005.531
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# >66, c1=-3895512.550, c2=163467.029, g=200381.188
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >67, c1=-4015042.400, c2=250517.448, g=308010.375
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# >68, c1=-4094464.750, c2=344398.737, g=243156.656
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# >69, c1=-4248271.700, c2=341818.475, g=98652.203
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# >70, c1=-4363453.700, c2=395592.250, g=69554.586
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# >71, c1=-4578357.800, c2=533814.463, g=-17323.125
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# >72, c1=-4803708.400, c2=522925.450, g=-73192.891
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# >73, c1=-4867825.200, c2=668513.262, g=-421728.875
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# >74, c1=-5172243.800, c2=606237.338, g=-238189.266
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# >75, c1=-5483567.700, c2=706322.488, g=-225008.453
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >76, c1=-5768953.400, c2=792741.887, g=-729651.438
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >77, c1=-6195454.900, c2=888920.938, g=-765467.500
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# >78, c1=-6405314.100, c2=826172.438, g=-681315.250
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >79, c1=-6661744.800, c2=771501.588, g=-636856.062
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# >80, c1=-6964026.800, c2=723231.988, g=-652199.125
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# >81, c1=-7341385.400, c2=669969.512, g=-652731.625
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# >82, c1=-7671010.700, c2=653801.662, g=-614982.625
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 6ms/step
# >83, c1=-8095526.000, c2=638309.050, g=-567504.125
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >84, c1=-8219100.100, c2=614346.275, g=-470550.094
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 9ms/step
# >85, c1=-8485080.800, c2=534337.781, g=-352415.000
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >86, c1=-8680652.700, c2=469942.463, g=-330442.719
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# >87, c1=-9051582.000, c2=378349.169, g=-277017.125
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >88, c1=-9522496.400, c2=315973.444, g=-195986.688
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >89, c1=-9716873.200, c2=196422.097, g=-145313.359
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >90, c1=-10102435.800, c2=176731.070, g=-63528.730
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >91, c1=-10661840.000, c2=69114.093, g=-36403.008
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# >92, c1=-11007792.400, c2=81953.547, g=6509.330
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >93, c1=-11094018.600, c2=42186.207, g=69837.938
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# >94, c1=-11510084.400, c2=24084.687, g=13007.443
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >95, c1=-11690136.800, c2=-5420.035, g=90496.312
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# >96, c1=-12228654.200, c2=-11848.579, g=139105.984
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# >97, c1=-12407769.200, c2=-24494.895, g=113546.273
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >98, c1=-12441317.600, c2=-3491.764, g=180704.219
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# >99, c1=-12883426.600, c2=-22047.877, g=190077.578
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# >100, c1=-13306908.200, c2=-77621.267, g=226907.062
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# >101, c1=-13644246.600, c2=-98823.414, g=295461.375
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >102, c1=-13695802.800, c2=-87082.709, g=222139.734
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >103, c1=-14262542.200, c2=-115732.223, g=307923.312
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# >104, c1=-14773139.200, c2=-141675.700, g=247946.375
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 966us/step
# >105, c1=-14795997.200, c2=-102542.250, g=341642.625
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >106, c1=-15142751.800, c2=-141952.561, g=408201.719
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >107, c1=-15953757.800, c2=-182201.753, g=421885.469
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >108, c1=-15595852.800, c2=-100048.061, g=380283.625
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >109, c1=-16399457.400, c2=-105033.427, g=387377.406
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >110, c1=-16893860.400, c2=-85738.289, g=466952.688
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# >111, c1=-16395785.800, c2=-102156.864, g=477820.188
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >112, c1=-17202214.000, c2=-169860.523, g=370254.312
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >113, c1=-17353577.400, c2=-195484.206, g=481423.656
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >114, c1=-18050378.000, c2=-225493.917, g=484471.438
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >115, c1=-18780199.600, c2=-75807.320, g=526952.250
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >116, c1=-19204928.400, c2=-159399.752, g=433259.250
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# >117, c1=-18842896.800, c2=-149555.159, g=474765.188
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >118, c1=-20050218.000, c2=-161012.848, g=552249.188
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >119, c1=-20002644.000, c2=-236480.616, g=551471.938
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# >120, c1=-20675455.200, c2=-197543.487, g=612489.000
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >121, c1=-20999322.000, c2=-304498.719, g=677800.812
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >122, c1=-21040040.800, c2=-176909.102, g=507756.062
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# >123, c1=-21411919.200, c2=-23735.748, g=611006.125
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >124, c1=-22097584.400, c2=-121637.371, g=539962.562
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >125, c1=-22032824.800, c2=-33987.431, g=546389.375
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >126, c1=-22763821.200, c2=-171415.087, g=565580.000
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >127, c1=-22196464.800, c2=-59171.517, g=611929.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >128, c1=-23028193.200, c2=-163911.599, g=578742.875
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >129, c1=-23246310.000, c2=-137199.214, g=664052.312
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >130, c1=-24303224.800, c2=-125358.078, g=606493.188
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 9ms/step
# >131, c1=-24574039.600, c2=-161643.735, g=641910.438
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# >132, c1=-24546784.800, c2=-177194.969, g=695114.625
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >133, c1=-25568892.000, c2=-181616.554, g=766534.625
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# >134, c1=-26603394.400, c2=-335973.266, g=687567.938
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# >135, c1=-26085927.200, c2=-301571.731, g=732507.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# >136, c1=-26540365.200, c2=-267850.391, g=704764.062
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# >137, c1=-27361123.600, c2=-265473.756, g=892555.125
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 61ms/step
# ...
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1570, c1=-3435777.100, c2=3931200.900, g=-3437072.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1571, c1=-3420906.150, c2=3732402.100, g=-3363061.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1572, c1=-3290592.200, c2=3674193.650, g=-3421144.250
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1573, c1=-3372102.200, c2=3802453.950, g=-3380960.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1574, c1=-3370544.500, c2=3897669.900, g=-3407857.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1575, c1=-3445230.850, c2=3860546.800, g=-3438482.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1576, c1=-3446350.500, c2=3861311.200, g=-3496500.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1577, c1=-3492652.550, c2=3906163.850, g=-3461843.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1578, c1=-3403280.150, c2=3721956.500, g=-3202488.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1579, c1=-3336012.150, c2=3793977.900, g=-3434329.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# >1580, c1=-3352249.300, c2=3637515.650, g=-3037251.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1581, c1=-2833317.400, c2=3404273.150, g=-2950565.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1582, c1=-3013674.350, c2=3391156.900, g=-3123354.000
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1583, c1=-2942225.950, c2=3387230.400, g=-3022425.750
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1584, c1=-3080219.500, c2=3418907.600, g=-2934489.000
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1585, c1=-2923405.900, c2=3388258.750, g=-3085066.000
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# >1586, c1=-3016465.700, c2=3433238.200, g=-2998125.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1587, c1=-2916685.950, c2=3382591.150, g=-3064819.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1588, c1=-3068489.550, c2=3433570.300, g=-2911060.500
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1589, c1=-2863663.200, c2=3395465.450, g=-3008655.250
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# >1590, c1=-3026350.850, c2=3381712.250, g=-2890496.250
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1591, c1=-3024615.550, c2=3406446.300, g=-2844738.250
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# >1592, c1=-2882150.250, c2=3366542.150, g=-2913260.000
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 3ms/step
# >1593, c1=-3079552.900, c2=3446897.500, g=-3218215.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1594, c1=-3011831.600, c2=3425701.150, g=-2647053.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 5ms/step
# >1595, c1=-2937765.300, c2=3416363.650, g=-3261970.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# >1596, c1=-3156500.950, c2=3460225.550, g=-2793532.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 1ms/step
# >1597, c1=-2863511.750, c2=3388752.800, g=-3070174.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# >1598, c1=-3006117.400, c2=3349798.200, g=-2832370.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# >1599, c1=-2951042.350, c2=3382690.750, g=-3120180.750
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1600, c1=-2965400.500, c2=3354962.700, g=-2849259.000
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# >1601, c1=-2865154.650, c2=3346950.000, g=-3145176.750
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1602, c1=-3095798.000, c2=3437379.600, g=-3017362.500
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1603, c1=-2950990.550, c2=3442033.350, g=-3095681.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1604, c1=-3036050.150, c2=3389023.650, g=-2822270.500
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1605, c1=-2988652.050, c2=3400444.050, g=-3011365.250
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# >1606, c1=-2914784.150, c2=3384859.900, g=-3099085.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 742us/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1607, c1=-3061866.850, c2=3413552.950, g=-3138280.000
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1608, c1=-2988418.850, c2=3413680.600, g=-3010624.000
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1609, c1=-2977797.900, c2=3387300.250, g=-3086257.000
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1610, c1=-2948047.600, c2=3346838.150, g=-2983519.500
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# >1611, c1=-2946151.450, c2=3368905.900, g=-3039240.000
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1612, c1=-2958810.450, c2=3354283.700, g=-2847568.000
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1613, c1=-2956326.900, c2=3371019.450, g=-3011260.250
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# >1614, c1=-2947415.500, c2=3344741.100, g=-2857858.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# >1615, c1=-2902903.750, c2=3360532.400, g=-3097557.000
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1616, c1=-3010698.700, c2=3345952.650, g=-2893479.750
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1617, c1=-2825475.950, c2=3333690.350, g=-3105743.000
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# >1618, c1=-3066825.450, c2=3396136.150, g=-2880118.500
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# >1619, c1=-2937563.100, c2=3408723.900, g=-2993835.750
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# >1620, c1=-2989102.150, c2=3403437.450, g=-3194058.500
# 4/4 [==============================] - 0s 35ms/step

# %%
plt.imshow(dataset[0,:,:,0])

# %% [markdown]
# # Generacion de Modelos

# %%
# create and save a plot of generated images (reversed grayscale)
def save_plot_predict(examples, n):
  # plot images
  for i in range(n * n):
    # define subplot
    plt.subplot(n, n, 1 + i)
    # turn off axis
    plt.axis('off')
    # plot raw pixel data
    plt.imshow(examples[i, :, :, 0], cmap='gray_r')
  plt.show()

# %%
# load model
model = load_model('generator_2D_model_100.h5')
# generate images
latent_points = generate_latent_points(100, 25)
# generate images
X = model.predict(latent_points)
# plot the result
save_plot_predict(X, 5)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[31], line 2
#       1 # load model
# ----> 2 model = load_model('generator_2D_model_100.h5')
#       3 # generate images
#       4 latent_points = generate_latent_points(100, 25)
#
# File ~\anaconda3\envs\gpu\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\anaconda3\envs\gpu\lib\site-packages\keras\saving\save.py:206, in load_model(filepath, custom_objects, compile, options)
#     204 if isinstance(filepath_str, str):
#     205   if not tf.io.gfile.exists(filepath_str):
# --> 206     raise IOError(f'No file or directory found at {filepath_str}')
#     208   if tf.io.gfile.isdir(filepath_str):
#     209     return saved_model_load.load(filepath_str, compile, options)
#
# OSError: No file or directory found at generator_2D_model_100.h5
